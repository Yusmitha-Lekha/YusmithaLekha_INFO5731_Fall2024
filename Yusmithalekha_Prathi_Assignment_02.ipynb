# %% [markdown]
# <a href="https://colab.research.google.com/github/Yusmitha-Lekha/YusmithaLekha_INFO5731_Fall2024/blob/main/Yusmithalekha_Prathi_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Tuesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Extracted and assigned the url of the imdb movie reviews page to the variable URL U
url = 'https://www.imdb.com/title/tt15239678/reviews/_ajax?ref_=undefined&paginationKey='

# Headers to mimic a real browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Initialized the  variables for the purpose of pagination and reviews
reviews = []
pagination_key = ''
total_reviews_needed = 1000  # top 1000 reviews

# Opened the  CSV file for the purpose of writing
with open('imdb_reviews.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Write header row

    # Loop to go through all the pages until we have enough(1000) reviews
    while len(reviews) < total_reviews_needed:
        # Construct the full URL with the pagination key
        full_url = url + pagination_key

        # Sending a GET request to  URL
        response = requests.get(full_url, headers=headers)

        # Parsing the page content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Finding all the review-containers
        new_reviews = soup.find_all('div', class_='text show-more__control')

        # If no new reviews are being found, break the loop which is (end of pages)
        if not new_reviews:
            print("No more reviews found.")
            break

        # Adding  the new reviews to the final or the total list
        for review in new_reviews:
            review_text = review.get_text().strip()
            if len(reviews) < total_reviews_needed:
                reviews.append(review_text)
                writer.writerow([review_text])
            else:
                break  # Break if we already have the 1000 reviews

        # Update the pagination key for the next page
        load_more_data = soup.find('div', {'class': 'load-more-data'})
        if load_more_data and load_more_data.has_attr('data-key'):
            pagination_key = load_more_data['data-key']
        else:
            break  # Break here, if no pagination key is being found

        # Pausing between requests to avoid being blocked
        time.sleep(1)

# Printing the number of reviews scraped
print(f'Scraped {len(reviews)} reviews successfully!')
# Out:
# Scraped 1000 reviews successfully!

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Downloading the NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
# Loading the reviews from the CSV file
dataFrame = pd.read_csv('imdb_reviews.csv')

# first few rows of the original data
dataFrame.head()
# Out:
#                                               Review
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...

# %% [markdown]
# # (1) Remove noise, such as special characters and punctuations.

# %%
# Function for removing the noise
def remove_noise(text):
    return re.sub(r'[^A-Za-z\s]', '', text)  # Keep only letters and whitespace

# Applying the function
dataFrame['Noisy Removed'] = dataFrame['Review'].apply(remove_noise)

# Displaying the updated DataFrame
dataFrame[['Review', 'Noisy Removed']].head()
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                        Noisy Removed
# 0  This is what Hollywood needs A great story wit...
# 1  Im going to write this as a review for both Du...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff Ill probably calm down tomorr...
# 4  If you liked or loved the first one the same w...

# %% [markdown]
# # (2) Remove numbers.

# %%
# Function to remove numbers
def remove_numbers(text):
    return re.sub(r'\d+', '', text)

# Apply the function
dataFrame['Numbers Removed'] = dataFrame['Noisy Removed'].apply(remove_numbers)

# Display the updated DataFrame
dataFrame[['Review', 'Numbers Removed']].head()
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                      Numbers Removed
# 0  This is what Hollywood needs A great story wit...
# 1  Im going to write this as a review for both Du...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff Ill probably calm down tomorr...
# 4  If you liked or loved the first one the same w...

# %% [markdown]
# # (3) Remove stopwords by using the stopwords list.

# %%
# Initializing the stopwords
stop_words = set(stopwords.words('english'))

# Function for removing the stopwords
def remove_stopwords(text):
    text_tokens = text.split()
    return ' '.join([word for word in text_tokens if word.lower() not in stop_words])

# Applying the function
dataFrame['Stopwords Removed'] = dataFrame['Numbers Removed'].apply(remove_stopwords)

# Displaying the updated DataFrame
dataFrame[['Review', 'Stopwords Removed']].head()
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                    Stopwords Removed
# 0  Hollywood needs great story great directorprod...
# 1  Im going write review Dune movies Ill include ...
# 2  pleasure watch film early screening completely...
# 3  Phenomenal stuff Ill probably calm tomorrow ri...
# 4  liked loved first one apply one Personally lov...

# %% [markdown]
# # (4) Lowercase all texts

# %%
# Function for lowercase all texts
def lowercase_text(text):
    return text.lower()

# Applying  function
dataFrame['Lowercased'] = dataFrame['Stopwords Removed'].apply(lowercase_text)

# Displaying the updated-DataFrame
dataFrame[['Review', 'Lowercased']].head()
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                           Lowercased
# 0  hollywood needs great story great directorprod...
# 1  im going write review dune movies ill include ...
# 2  pleasure watch film early screening completely...
# 3  phenomenal stuff ill probably calm tomorrow ri...
# 4  liked loved first one apply one personally lov...

# %% [markdown]
# # (5) Stemming.

# %%
# Initializing the stemmer
stemmer = PorterStemmer()

# Function for the purpose of stemming
def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

# Applying  the function
dataFrame['Stemmed'] = dataFrame['Lowercased'].apply(stem_text)

# Displaying  the updated-DataFrame
dataFrame[['Review', 'Stemmed']].head()
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                              Stemmed
# 0  hollywood need great stori great directorprodu...
# 1  im go write review dune movi ill includ though...
# 2  pleasur watch film earli screen complet blown ...
# 3  phenomen stuff ill probabl calm tomorrow right...
# 4  like love first one appli one person love one ...

# %% [markdown]
# # (6) Lemmatization.

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 6.8 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24

# %%
import pandas as pd
import spacy
import contractions

# Loading  the English NLP model
nlp = spacy.load('en_core_web_sm')


# Function to expand contractions
def expand_contractions(text):
    return contractions.fix(text)

# Function for lemmatization using spaCy
def lemmatize_text(text):
    doc = nlp(text)
    return ' '.join([token.lemma_ for token in doc])

# Applying the function to expand contractions and then lemmatize
dataFrame['Lemmatized'] = dataFrame['Stemmed'].apply(expand_contractions).apply(lemmatize_text)

# Displaying the updated DataFrame
print(dataFrame[['Review', 'Lemmatized']].head())
# Out:
#                                               Review  \
# 0  This is what Hollywood needs. A great story wi...
# 1  I'm going to write this as a review for both D...
# 2  Had the pleasure to watch this film in an earl...
# 3  Phenomenal stuff. I'll probably calm down tomo...
# 4  If you liked or loved the first one, the same ...
#
#                                           Lemmatized
# 0  hollywood need great stori great directorprodu...
# 1  I be go write review dune movi ill includ thin...
# 2  pleasur watch film earli screen complet blow a...
# 3  phenomen stuff ill probabl calm tomorrow right...
# 4  like love first one appli one person love one ...

# %%
# Saving the cleaned-data to a new CSV file which is called as imdb_reviews_cleaned
dataFrame.to_csv('imdb_reviews_cleaned.csv', index=False)

# Print a confirmation message
print("Cleaned data saved to 'imdb_reviews_cleaned.csv'")
# Out:
# Cleaned data saved to 'imdb_reviews_cleaned.csv'

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %% [markdown]
# # (1) Parts of Speech (POS) Tagging

# %%
import nltk
import pandas as pd
from collections import Counter

# Downloading all  necessary NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

def pos_tagging(text):
    words = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(words)
    return pos_tags

def count_pos(pos_tags):
    pos_counts = Counter(tag for word, tag in pos_tags)
    return {
        'Nouns': sum(pos_counts[tag] for tag in ['NN', 'NNS', 'NNP', 'NNPS']),
        'Verbs': sum(pos_counts[tag] for tag in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']),
        'Adjectives': sum(pos_counts[tag] for tag in ['JJ', 'JJR', 'JJS']),
        'Adverbs': sum(pos_counts[tag] for tag in ['RB', 'RBR', 'RBS'])
    }

# Loading the cleaned-data
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Performing the  POS tagging on  cleaned-text
dataFrame['POS_tags'] = dataFrame['Lemmatized'].apply(pos_tagging)

# Counting the  POS for each and every review
dataFrame['POS_counts'] = dataFrame['POS_tags'].apply(count_pos)

# Calculating the  total POS counts
total_pos_counts = dataFrame['POS_counts'].apply(pd.Series).sum()

print("Total POS counts:")
print(total_pos_counts)

# Saving all the  results to CSV file
dataFrame.to_csv('imdb_reviews_pos_tagged.csv', index=False)
print("POS tagging results saved to 'imdb_reviews_pos_tagged.csv'")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Total POS counts:
# Nouns         61873
# Verbs         15913
# Adjectives    22720
# Adverbs        6796
# dtype: int64
# POS tagging results saved to 'imdb_reviews_pos_tagged.csv'

# %% [markdown]
# # (2) Constituency Parsing and Dependency Parsing

# %%
import nltk
import spacy
from nltk import Tree
import pandas as pd

# Downloading all the  necessary NLTK data
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('words', quiet=True)

# Loading the  spaCy model
nlp = spacy.load("en_core_web_sm")

def constituency_parse(sentence):
    words = nltk.word_tokenize(sentence)
    pos_tags = nltk.pos_tag(words)
    tree = nltk.ne_chunk(pos_tags)
    return tree

def dependency_parse(sentence):
    doc = nlp(sentence)
    return [(token.text, token.dep_, token.head.text) for token in doc]

# Loading  the cleaned-data from csv file
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Processing all the sentences
for index, row in dataFrame.iterrows():
    sentence = row['Lemmatized']
    print(f"\n\nSentence {index + 1}:")
    print(sentence)

    try:
        print("\nConstituency Parse Tree:")
        constituency_tree = constituency_parse(sentence)
        print(constituency_tree)
    except LookupError as e:
        print(f"Error in constituency parsing: {e}")

    print("\nDependency Parse:")
    dependency_relations = dependency_parse(sentence)
    for word, dep, head in dependency_relations:
        print(f"{word} --{dep}--> {head}")

print("\nParsing completed for all sentences.")
# Out:
# Streaming output truncated to the last 5000 lines.
# sand --nsubj--> hide
# hide --ccomp--> make
# leav --amod--> trail
# clear --amod--> trail
# trail --dobj--> hide
# behind --prep--> hide
# find --advcl--> watch
# scatteredoveral --amod--> doubt
# enjoy --amod--> doubt
# movi --compound--> doubt
# doubt --nsubj--> watch
# watch --ccomp--> bloat
#
#
# Sentence 987:
# think mani thing talk movi let keep simpl film absolut incre masterpiec work art besid think also one import film ever make accomplish much mani level exampl last time see sciencefict movi masterclass act deep charact perfect cinematographi immacul sound design list could go adapt novel specif believ film show we true power cgi use properli nearli invis blend perfectli rest footag deni villeneuv take we somewher one ever truli undescrib experi make perfect use wide shot lens filter ad immacul sound design han zimmer yet make incred origin score villeneuv compliment perfect background nois one thing sure though movi see theatr good theatr experi ever go see highli recommend go see leav go stream
#
# Constituency Parse Tree:
# (S
#   think/VB
#   mani/JJ
#   thing/NN
#   talk/NN
#   movi/NN
#   let/NN
#   keep/VB
#   simpl/NN
#   film/NN
#   absolut/JJ
#   incre/NN
#   masterpiec/NN
#   work/NN
#   art/RB
#   besid/NN
#   think/NN
#   also/RB
#   one/CD
#   import/NN
#   film/NN
#   ever/RB
#   make/VB
#   accomplish/JJ
#   much/JJ
#   mani/JJR
#   level/NN
#   exampl/IN
#   last/JJ
#   time/NN
#   see/VB
#   sciencefict/JJ
#   movi/NNS
#   masterclass/NN
#   act/NN
#   deep/JJ
#   charact/NN
#   perfect/JJ
#   cinematographi/NN
#   immacul/NN
#   sound/NN
#   design/NN
#   list/NN
#   could/MD
#   go/VB
#   adapt/RP
#   novel/JJ
#   specif/NN
#   believ/NN
#   film/NN
#   show/NN
#   we/PRP
#   true/JJ
#   power/NN
#   cgi/NN
#   use/NN
#   properli/NN
#   nearli/NN
#   invis/JJ
#   blend/NN
#   perfectli/NN
#   rest/NN
#   footag/NN
#   deni/NN
#   villeneuv/NNS
#   take/VBP
#   we/PRP
#   somewher/VBP
#   one/CD
#   ever/RB
#   truli/VBZ
#   undescrib/JJ
#   experi/NNS
#   make/VBP
#   perfect/JJ
#   use/NN
#   wide/JJ
#   shot/NN
#   lens/NNS
#   filter/VBP
#   ad/NN
#   immacul/NN
#   sound/NN
#   design/NN
#   han/NN
#   zimmer/NN
#   yet/RB
#   make/VB
#   incred/JJ
#   origin/NN
#   score/NN
#   villeneuv/NN
#   compliment/NN
#   perfect/NN
#   background/IN
#   nois/FW
#   one/CD
#   thing/NN
#   sure/JJ
#   though/IN
#   movi/JJ
#   see/NN
#   theatr/RB
#   good/JJ
#   theatr/NN
#   experi/NN
#   ever/RB
#   go/VB
#   see/VB
#   highli/JJ
#   recommend/VB
#   go/VB
#   see/VB
#   leav/RB
#   go/VB
#   stream/NN)
#
# Dependency Parse:
# think --ROOT--> think
# mani --compound--> movi
# thing --compound--> movi
# talk --compound--> movi
# movi --nsubj--> let
# let --ccomp--> think
# keep --xcomp--> let
# simpl --dobj--> keep
# film --compound--> masterpiec
# absolut --compound--> masterpiec
# incre --compound--> masterpiec
# masterpiec --compound--> art
# work --compound--> art
# art --compound--> besid
# besid --npadvmod--> keep
# think --ccomp--> let
# also --advmod--> think
# one --nummod--> film
# import --compound--> film
# film --nsubj--> make
# ever --advmod--> make
# make --ccomp--> think
# accomplish --amod--> exampl
# much --amod--> exampl
# mani --amod--> level
# level --compound--> exampl
# exampl --dobj--> make
# last --amod--> time
# time --npadvmod--> make
# see --ccomp--> think
# sciencefict --compound--> act
# movi --compound--> masterclass
# masterclass --compound--> act
# act --nmod--> list
# deep --amod--> charact
# charact --npadvmod--> perfect
# perfect --amod--> list
# cinematographi --compound--> list
# immacul --compound--> list
# sound --compound--> list
# design --compound--> list
# list --nsubj--> go
# could --aux--> go
# go --ccomp--> see
# adapt --advcl--> go
# novel --amod--> specif
# specif --compound--> film
# believ --compound--> film
# film --npadvmod--> adapt
# show --advcl--> go
# we --dative--> show
# true --amod--> power
# power --nsubj--> use
# cgi --nsubj--> use
# use --ccomp--> show
# properli --dobj--> use
# nearli --dobj--> use
# invis --nsubj--> blend
# blend --xcomp--> use
# perfectli --compound--> rest
# rest --compound--> footag
# footag --dobj--> blend
# deni --compound--> villeneuv
# villeneuv --nsubj--> take
# take --ccomp--> think
# we --nsubj--> somewher
# somewher --ccomp--> take
# one --dobj--> somewher
# ever --advmod--> truli
# truli --advcl--> somewher
# undescrib --compound--> experi
# experi --nsubj--> make
# make --ROOT--> make
# perfect --amod--> use
# use --compound--> zimmer
# wide --amod--> lens
# shot --compound--> lens
# lens --compound--> zimmer
# filter --compound--> zimmer
# ad --compound--> immacul
# immacul --compound--> zimmer
# sound --compound--> zimmer
# design --compound--> han
# han --compound--> zimmer
# zimmer --dobj--> make
# yet --cc--> make
# make --conj--> make
# incred --amod--> score
# origin --compound--> score
# score --dobj--> make
# villeneuv --prep--> make
# compliment --amod--> background
# perfect --amod--> background
# background --dobj--> make
# nois --nmod--> thing
# one --nummod--> thing
# thing --dobj--> make
# sure --advcl--> make
# though --mark--> see
# movi --nsubj--> see
# see --advcl--> make
# theatr --amod--> theatr
# good --amod--> theatr
# theatr --dobj--> see
# experi --advcl--> make
# ever --advmod--> go
# go --ccomp--> make
# see --advcl--> go
# highli --compound--> recommend
# recommend --nsubj--> go
# go --nsubj--> see
# see --ccomp--> see
# leav --nsubj--> go
# go --nsubj--> stream
# stream --ccomp--> see
#
#
# Sentence 988:
# do not understand high score movi long draw scene constant accompani nois back ground music continu nois similar fog horn time movi could halv remov artist licenseoveral though bore realli realli dullid love leav requir minimum word count make review interest ill tell weather inver today strong gale forc westerli intermitt shower rain hail wish read good day
#
# Constituency Parse Tree:
# (S
#   do/VB
#   not/RB
#   understand/VB
#   high/JJ
#   score/NN
#   movi/NN
#   long/JJ
#   draw/JJ
#   scene/NN
#   constant/JJ
#   accompani/NN
#   nois/NN
#   back/RB
#   ground/NN
#   music/NN
#   continu/NN
#   nois/IN
#   similar/JJ
#   fog/NN
#   horn/JJ
#   time/NN
#   movi/NN
#   could/MD
#   halv/VB
#   remov/JJ
#   artist/JJ
#   licenseoveral/JJ
#   though/IN
#   bore/RB
#   realli/JJ
#   realli/NN
#   dullid/JJ
#   love/NN
#   leav/NN
#   requir/NN
#   minimum/JJ
#   word/NN
#   count/NN
#   make/VBP
#   review/NN
#   interest/NN
#   ill/NN
#   tell/VB
#   weather/JJR
#   inver/NN
#   today/NN
#   strong/JJ
#   gale/NN
#   forc/NN
#   westerli/NN
#   intermitt/NN
#   shower/NN
#   rain/NN
#   hail/JJ
#   wish/JJ
#   read/NN
#   good/JJ
#   day/NN)
#
# Dependency Parse:
# do --aux--> understand
# not --neg--> understand
# understand --ROOT--> understand
# high --amod--> movi
# score --compound--> movi
# movi --nsubj--> draw
# long --advmod--> draw
# draw --ccomp--> understand
# scene --compound--> nois
# constant --amod--> nois
# accompani --compound--> nois
# nois --amod--> movi
# back --amod--> ground
# ground --compound--> music
# music --compound--> nois
# continu --compound--> nois
# nois --compound--> movi
# similar --amod--> movi
# fog --compound--> horn
# horn --compound--> time
# time --compound--> movi
# movi --nsubj--> halv
# could --aux--> halv
# halv --ccomp--> draw
# remov --compound--> artist
# artist --dobj--> halv
# licenseoveral --advcl--> halv
# though --prep--> understand
# bore --compound--> realli
# realli --compound--> realli
# realli --pobj--> though
# dullid --compound--> love
# love --nmod--> requir
# leav --compound--> requir
# requir --compound--> word
# minimum --amod--> word
# word --compound--> count
# count --nsubj--> make
# make --ccomp--> understand
# review --compound--> interest
# interest --compound--> ill
# ill --nsubj--> tell
# tell --compound--> weather
# weather --compound--> inver
# inver --ccomp--> make
# today --npadvmod--> inver
# strong --amod--> westerli
# gale --compound--> westerli
# forc --compound--> westerli
# westerli --nsubj--> intermitt
# intermitt --conj--> understand
# shower --compound--> hail
# rain --compound--> hail
# hail --compound--> wish
# wish --nsubj--> read
# read --ccomp--> intermitt
# good --amod--> day
# day --npadvmod--> read
#
#
# Sentence 989:
# dune part two univer hail sequel worthi termin judgment day godfath part ii empir strike back bonafid epic yield addit comparison benhur lawrenc arabia pictur solidifi deni villeneuv one modern titan art form even be not hot first film find charact monoton visual larg dull seem thoroughli overand although enjoy visual thought purpos occasion drab impos brutalist structur tower natur new film inde crank art direct eleven exemplifi potent visual scifi histori although think charact work fine origin sequel treat powerhous newcom darker depth figur know critic say like dune part one fine can not buy timoth chalamet hero reader frank herbert novel snicker part two new fan see whyif noth el find whole thing feel complet recal first movi bamboozl mani have not clue part one frank herbert son brian write new movi combin dune part one far good film interpret dune ever doneoth thing expand andor elev includ perform zendaya one express loveabl actor gener underus prior movi chani young fremen warrior welcom paul atreid camp fall hous rebecca ferguson ladi jessica paul mother becom reverend mother fremen believ paul instrument propheci mother child send reclaim planet arraki oppress imperi spicemin coloni belong vile harkonnen famili note also get well look harkonnen homeworld whose black sun seem era color bar black black whitest whitethi moment one mani reason need see theater can not stress enough sequenc thunder battl sandworm ride intim final duel leave audienc edg seat paralyz behold auditorium complet music sound design seem make earth trembl fall dead silent pivot moment sublim photograph swirli bokeh extraordinair greig fraser often see film know your wit creation icon imag action scene elev impress choreographi cour performancesth inten new face undoubtedli austin butler feyd rautha that sting charact movi case need refer laud mani good villain perform sinc anton chigurh ledger joker addit newcom includ florenc pugh princess irulan la seydoux ladi fenr bene gesseret priestess christoph walken emperor shaddam ivreturn actor includ javier bardem fremen leader stilgar whose incorrig fanatic get big laugh josh brolin gurney halleck harkonnen blood stellan skarsgrd revolt baron harkonnen dave bautista beast rabban envi affect baron show toward feyd charlott rampl imperi reverend mother hatch scheme certain charact I have mention give minut screen time yet make consider impact memor line read look speak even louder notabl final exchang haunt glanc paul chani princessat center chalamet paul muaddib atreid perform vindic stan make nonbeliev hope realiz formid truli go part one chalamet know thin frame friendli demeanor yet absolut troubl believ paul would master spar conqueror sandworm write early judg first movi well stori work gardenvarieti hero journey bind oh moment twoif your still worri element seem lift work recal dune like old seri whatev your think even familiar imag feel new epic scale way cinema have not abl achiev movi closetoperfect marriag hitherto unthink technolog crystalclear vision say tech realiz part movi play villeneuv hear complaint previou film dare go way movi magic sequel put doubter placeknow book go know franchis far do despit long film never want end still crave ergo I be stoke see villeneuv rest herbert legendarium audienc keep find reson version world dune uniqu wellreal potenti futur intimidatingli immen outlandish one hand dread convinc show imperi coloni may aliv well millennia ahead film make even less studio interfer parallel fremen plight palestin may even obviousth stori dune messiah still need adapt I be confid villeneuv show we medium illiter start post film twitter take poor thing approv misogyni film come digit will not take paul white savior jessica cultur appropri face valu may hope interest theori walter chaw suggest reason mani peopl keep fail get point dune paul atreid specif coloni embed valu system manifest destini straightup imposs we interpret figur like anyth good guy lisan algaib
#
# Constituency Parse Tree:
# (S
#   dune/JJ
#   part/NN
#   two/CD
#   univer/JJ
#   hail/NN
#   sequel/NN
#   worthi/NN
#   termin/JJ
#   judgment/NN
#   day/NN
#   godfath/VB
#   part/NN
#   ii/NN
#   empir/NN
#   strike/NN
#   back/RB
#   bonafid/JJ
#   epic/NN
#   yield/NN
#   addit/NN
#   comparison/NN
#   benhur/NN
#   lawrenc/NN
#   arabia/NN
#   pictur/NN
#   solidifi/NN
#   deni/NN
#   villeneuv/VBP
#   one/CD
#   modern/JJ
#   titan/JJ
#   art/NN
#   form/NN
#   even/RB
#   be/VB
#   not/RB
#   hot/JJ
#   first/JJ
#   film/NN
#   find/VB
#   charact/JJ
#   monoton/NN
#   visual/JJ
#   larg/NN
#   dull/NN
#   seem/VBP
#   thoroughli/RB
#   overand/VBP
#   although/IN
#   enjoy/JJ
#   visual/JJ
#   thought/NN
#   purpos/NN
#   occasion/NN
#   drab/NN
#   impos/JJ
#   brutalist/NN
#   structur/NN
#   tower/NN
#   natur/IN
#   new/JJ
#   film/NN
#   inde/NN
#   crank/NN
#   art/NN
#   direct/JJ
#   eleven/RB
#   exemplifi/VBP
#   potent/JJ
#   visual/JJ
#   scifi/NN
#   histori/VBD
#   although/IN
#   think/NN
#   charact/JJ
#   work/NN
#   fine/JJ
#   origin/NN
#   sequel/NN
#   treat/NN
#   powerhous/JJ
#   newcom/NN
#   darker/NN
#   depth/NN
#   figur/NN
#   know/VBP
#   critic/JJ
#   say/VBP
#   like/IN
#   dune/JJ
#   part/NN
#   one/CD
#   fine/NN
#   can/MD
#   not/RB
#   buy/VB
#   timoth/JJ
#   chalamet/NN
#   hero/NN
#   reader/NN
#   frank/VBD
#   herbert/JJ
#   novel/NN
#   snicker/NN
#   part/NN
#   two/CD
#   new/JJ
#   fan/NN
#   see/VBP
#   whyif/JJ
#   noth/DT
#   el/JJ
#   find/VBP
#   whole/JJ
#   thing/NN
#   feel/NN
#   complet/NN
#   recal/JJ
#   first/JJ
#   movi/NN
#   bamboozl/NN
#   mani/NNS
#   have/VBP
#   not/RB
#   clue/JJ
#   part/NN
#   one/CD
#   frank/NN
#   herbert/NN
#   son/NN
#   brian/JJ
#   write/JJ
#   new/JJ
#   movi/NN
#   combin/NN
#   dune/JJ
#   part/NN
#   one/CD
#   far/RB
#   good/JJ
#   film/NN
#   interpret/NN
#   dune/NN
#   ever/RB
#   doneoth/JJ
#   thing/NN
#   expand/NN
#   andor/NN
#   elev/NN
#   includ/NN
#   perform/NN
#   zendaya/NN
#   one/CD
#   express/NN
#   loveabl/NN
#   actor/NN
#   gener/NN
#   underus/JJ
#   prior/JJ
#   movi/NN
#   chani/NN
#   young/JJ
#   fremen/NNS
#   warrior/JJ
#   welcom/NN
#   paul/NN
#   atreid/NN
#   camp/NN
#   fall/VBP
#   hous/JJ
#   rebecca/NN
#   ferguson/NN
#   ladi/NN
#   jessica/NN
#   paul/NN
#   mother/NN
#   becom/VBD
#   reverend/VBP
#   mother/NN
#   fremen/NNS
#   believ/VBP
#   paul/JJ
#   instrument/NN
#   propheci/NN
#   mother/NN
#   child/JJ
#   send/NN
#   reclaim/NN
#   planet/NN
#   arraki/NN
#   oppress/NN
#   imperi/NN
#   spicemin/NN
#   coloni/NN
#   belong/RB
#   vile/JJ
#   harkonnen/NN
#   famili/NN
#   note/NN
#   also/RB
#   get/VBP
#   well/RB
#   look/VB
#   harkonnen/JJ
#   homeworld/NN
#   whose/WP$
#   black/JJ
#   sun/NN
#   seem/VBP
#   era/NN
#   color/NN
#   bar/NN
#   black/JJ
#   black/JJ
#   whitest/JJS
#   whitethi/JJ
#   moment/NN
#   one/CD
#   mani/NN
#   reason/NN
#   need/MD
#   see/VB
#   theater/NN
#   can/MD
#   not/RB
#   stress/VB
#   enough/RB
#   sequenc/JJ
#   thunder/NN
#   battl/NN
#   sandworm/NN
#   ride/NN
#   intim/JJ
#   final/JJ
#   duel/NN
#   leave/VBP
#   audienc/VBN
#   edg/JJ
#   seat/NN
#   paralyz/NN
#   behold/VBD
#   auditorium/JJ
#   complet/NN
#   music/NN
#   sound/NN
#   design/NN
#   seem/VBP
#   make/VB
#   earth/NN
#   trembl/VB
#   fall/NN
#   dead/JJ
#   silent/JJ
#   pivot/NN
#   moment/NN
#   sublim/NN
#   photograph/NN
#   swirli/NN
#   bokeh/NN
#   extraordinair/NN
#   greig/FW
#   fraser/NN
#   often/RB
#   see/VBP
#   film/NN
#   know/VB
#   your/PRP$
#   wit/JJ
#   creation/NN
#   icon/NN
#   imag/JJ
#   action/NN
#   scene/NN
#   elev/NN
#   impress/NN
#   choreographi/VB
#   cour/JJ
#   performancesth/NN
#   inten/VBP
#   new/JJ
#   face/NN
#   undoubtedli/JJ
#   austin/JJ
#   butler/NN
#   feyd/NN
#   rautha/NN
#   that/IN
#   sting/VBG
#   charact/NN
#   movi/NN
#   case/NN
#   need/VBP
#   refer/VBP
#   laud/JJ
#   mani/NN
#   good/JJ
#   villain/NN
#   perform/NN
#   sinc/NN
#   anton/NN
#   chigurh/NN
#   ledger/NN
#   joker/NN
#   addit/NN
#   newcom/NN
#   includ/NN
#   florenc/NN
#   pugh/IN
#   princess/NN
#   irulan/NN
#   la/VBP
#   seydoux/JJ
#   ladi/NN
#   fenr/NN
#   bene/NN
#   gesseret/JJ
#   priestess/NN
#   christoph/NN
#   walken/WRB
#   emperor/NN
#   shaddam/NN
#   ivreturn/NN
#   actor/NN
#   includ/NN
#   javier/NN
#   bardem/JJ
#   fremen/NNS
#   leader/NN
#   stilgar/NN
#   whose/WP$
#   incorrig/NN
#   fanatic/JJ
#   get/NN
#   big/JJ
#   laugh/NN
#   josh/NN
#   brolin/NN
#   gurney/NN
#   halleck/NN
#   harkonnen/NN
#   blood/NN
#   stellan/NN
#   skarsgrd/VBD
#   revolt/JJ
#   baron/NN
#   harkonnen/NN
#   dave/VBP
#   bautista/VBN
#   beast/JJ
#   rabban/JJ
#   envi/NN
#   affect/VBP
#   baron/NN
#   show/NN
#   toward/IN
#   feyd/JJ
#   charlott/NN
#   rampl/NN
#   imperi/JJ
#   reverend/NN
#   mother/NN
#   hatch/NN
#   scheme/NN
#   certain/JJ
#   charact/NN
#   I/PRP
#   have/VBP
#   mention/VBN
#   give/JJ
#   minut/NN
#   screen/NN
#   time/NN
#   yet/RB
#   make/VB
#   consider/JJR
#   impact/NN
#   memor/NN
#   line/NN
#   read/VBN
#   look/VBP
#   speak/JJ
#   even/RB
#   louder/RBR
#   notabl/JJ
#   final/JJ
#   exchang/NN
#   haunt/NN
#   glanc/NN
#   paul/NN
#   chani/NN
#   princessat/NN
#   center/NN
#   chalamet/NN
#   paul/NN
#   muaddib/NN
#   atreid/NN
#   perform/NN
#   vindic/JJ
#   stan/NNS
#   make/VBP
#   nonbeliev/JJ
#   hope/NN
#   realiz/NN
#   formid/NN
#   truli/NN
#   go/VBP
#   part/NN
#   one/CD
#   chalamet/NN
#   know/VBP
#   thin/JJ
#   frame/NN
#   friendli/JJ
#   demeanor/NN
#   yet/RB
#   absolut/JJ
#   troubl/NN
#   believ/NN
#   paul/NN
#   would/MD
#   master/VB
#   spar/JJ
#   conqueror/NN
#   sandworm/NN
#   write/VBP
#   early/JJ
#   judg/NN
#   first/RB
#   movi/RB
#   well/RB
#   stori/JJ
#   work/NN
#   gardenvarieti/NN
#   hero/NN
#   journey/NN
#   bind/NN
#   oh/JJ
#   moment/NN
#   twoif/IN
#   your/PRP$
#   still/RB
#   worri/JJ
#   element/NN
#   seem/VBP
#   lift/JJ
#   work/NN
#   recal/JJ
#   dune/NN
#   like/IN
#   old/JJ
#   seri/JJ
#   whatev/VB
#   your/PRP$
#   think/NN
#   even/RB
#   familiar/JJ
#   imag/NNS
#   feel/VBP
#   new/JJ
#   epic/NNS
#   scale/JJ
#   way/NN
#   cinema/NNS
#   have/VBP
#   not/RB
#   abl/VBN
#   achiev/JJ
#   movi/NN
#   closetoperfect/NN
#   marriag/NN
#   hitherto/NN
#   unthink/VBP
#   technolog/NN
#   crystalclear/JJ
#   vision/NN
#   say/VBP
#   tech/NN
#   realiz/JJ
#   part/NN
#   movi/NN
#   play/NN
#   villeneuv/NN
#   hear/VBP
#   complaint/NN
#   previou/NN
#   film/NN
#   dare/NN
#   go/VB
#   way/NN
#   movi/FW
#   magic/JJ
#   sequel/NN
#   put/VBD
#   doubter/RB
#   placeknow/JJ
#   book/NN
#   go/VBP
#   know/VB
#   franchis/RB
#   far/RB
#   do/VBP
#   despit/NNS
#   long/RB
#   film/NN
#   never/RB
#   want/VBP
#   end/NN
#   still/RB
#   crave/VBP
#   ergo/NN
#   I/PRP
#   be/VB
#   stoke/VBN
#   see/VB
#   villeneuv/JJ
#   rest/NN
#   herbert/NN
#   legendarium/NN
#   audienc/JJ
#   keep/VB
#   find/IN
#   reson/JJ
#   version/NN
#   world/NN
#   dune/NN
#   uniqu/JJ
#   wellreal/NN
#   potenti/NN
#   futur/NN
#   intimidatingli/JJ
#   immen/NNS
#   outlandish/JJ
#   one/CD
#   hand/NN
#   dread/NN
#   convinc/NN
#   show/NN
#   imperi/JJ
#   coloni/NN
#   may/MD
#   aliv/VB
#   well/RB
#   millennia/RB
#   ahead/RB
#   film/NN
#   make/VB
#   even/RB
#   less/JJR
#   studio/NN
#   interfer/NN
#   parallel/JJ
#   fremen/NNS
#   plight/VBD
#   palestin/NN
#   may/MD
#   even/RB
#   obviousth/VB
#   stori/JJR
#   dune/NN
#   messiah/NN
#   still/RB
#   need/VB
#   adapt/NN
#   I/PRP
#   be/VB
#   confid/VBN
#   villeneuv/JJ
#   show/NN
#   we/PRP
#   medium/VBP
#   illiter/JJ
#   start/VBP
#   post/NN
#   film/NN
#   twitter/NN
#   take/VB
#   poor/JJ
#   thing/NN
#   approv/NN
#   misogyni/NN
#   film/NN
#   come/VBN
#   digit/NN
#   will/MD
#   not/RB
#   take/VB
#   paul/NN
#   white/JJ
#   savior/NN
#   jessica/NN
#   cultur/NN
#   appropri/JJ
#   face/NN
#   valu/NN
#   may/MD
#   hope/VB
#   interest/NN
#   theori/NN
#   walter/NN
#   chaw/NN
#   suggest/VBP
#   reason/NN
#   mani/NN
#   peopl/NN
#   keep/VB
#   fail/JJ
#   get/NN
#   point/NN
#   dune/NN
#   paul/NN
#   atreid/NN
#   specif/NN
#   coloni/NN
#   embed/VBD
#   valu/JJ
#   system/NN
#   manifest/JJS
#   destini/NN
#   straightup/NN
#   imposs/IN
#   we/PRP
#   interpret/VBP
#   figur/NNS
#   like/IN
#   anyth/RB
#   good/JJ
#   guy/NN
#   lisan/NNS
#   algaib/VBP)
#
# Dependency Parse:
# dune --amod--> part
# part --nsubj--> sequel
# two --nummod--> part
# univer --amod--> sequel
# hail --compound--> sequel
# sequel --nsubj--> strike
# worthi --compound--> termin
# termin --compound--> judgment
# judgment --compound--> day
# day --compound--> empir
# godfath --compound--> part
# part --compound--> ii
# ii --compound--> empir
# empir --nsubj--> strike
# strike --nsubj--> find
# back --advmod--> strike
# bonafid --amod--> comparison
# epic --amod--> comparison
# yield --compound--> addit
# addit --compound--> comparison
# comparison --dobj--> strike
# benhur --conj--> strike
# lawrenc --compound--> solidifi
# arabia --compound--> solidifi
# pictur --compound--> solidifi
# solidifi --dobj--> benhur
# deni --npadvmod--> benhur
# villeneuv --prep--> strike
# one --nummod--> form
# modern --amod--> form
# titan --compound--> form
# art --compound--> form
# form --nsubj--> be
# even --advmod--> be
# be --conj--> strike
# not --neg--> be
# hot --amod--> film
# first --amod--> film
# film --attr--> be
# find --ROOT--> find
# charact --compound--> monoton
# monoton --nmod--> larg
# visual --amod--> larg
# larg --nsubj--> seem
# dull --amod--> larg
# seem --ccomp--> find
# thoroughli --compound--> overand
# overand --oprd--> seem
# although --mark--> enjoy
# enjoy --advcl--> buy
# visual --amod--> thought
# thought --compound--> tower
# purpos --compound--> occasion
# occasion --compound--> tower
# drab --compound--> tower
# impos --compound--> brutalist
# brutalist --compound--> tower
# structur --compound--> tower
# tower --dobj--> enjoy
# natur --nmod--> film
# new --amod--> film
# film --nsubj--> inde
# inde --ccomp--> enjoy
# crank --compound--> art
# art --npadvmod--> direct
# direct --amod--> histori
# eleven --nummod--> histori
# exemplifi --nmod--> potent
# potent --amod--> histori
# visual --amod--> scifi
# scifi --compound--> histori
# histori --dobj--> inde
# although --mark--> think
# think --advcl--> enjoy
# charact --nsubj--> work
# work --ccomp--> think
# fine --amod--> origin
# origin --compound--> sequel
# sequel --compound--> treat
# treat --compound--> figur
# powerhous --amod--> figur
# newcom --compound--> darker
# darker --compound--> figur
# depth --compound--> figur
# figur --nsubj--> know
# know --ccomp--> think
# critic --nsubj--> say
# say --ccomp--> think
# like --intj--> say
# dune --amod--> part
# part --pobj--> like
# one --nummod--> fine
# fine --nsubj--> buy
# can --aux--> buy
# not --neg--> buy
# buy --ccomp--> see
# timoth --det--> hero
# chalamet --compound--> hero
# hero --compound--> snicker
# reader --compound--> snicker
# frank --compound--> herbert
# herbert --compound--> snicker
# novel --compound--> snicker
# snicker --compound--> part
# part --dobj--> buy
# two --nummod--> fan
# new --amod--> fan
# fan --nsubj--> see
# see --ccomp--> find
# whyif --compound--> el
# noth --compound--> el
# el --nsubj--> find
# find --ccomp--> see
# whole --amod--> thing
# thing --nsubj--> feel
# feel --ccomp--> find
# complet --compound--> mani
# recal --amod--> mani
# first --amod--> movi
# movi --compound--> mani
# bamboozl --compound--> mani
# mani --nsubj--> clue
# have --aux--> clue
# not --neg--> clue
# clue --ccomp--> feel
# part --dobj--> clue
# one --nummod--> brian
# frank --compound--> herbert
# herbert --compound--> son
# son --compound--> brian
# brian --nsubj--> write
# write --ccomp--> clue
# new --amod--> movi
# movi --dobj--> write
# combin --prep--> clue
# dune --compound--> part
# part --pobj--> combin
# one --nummod--> film
# far --advmod--> good
# good --amod--> film
# film --nsubj--> interpret
# interpret --conj--> find
# dune --dobj--> interpret
# ever --advmod--> doneoth
# doneoth --compound--> thing
# thing --nsubj--> expand
# expand --ccomp--> find
# andor --dobj--> expand
# elev --advmod--> expand
# includ --nsubj--> perform
# perform --ccomp--> expand
# zendaya --npadvmod--> find
# one --nummod--> underus
# express --amod--> underus
# loveabl --amod--> actor
# actor --compound--> underus
# gener --compound--> underus
# underus --nmod--> warrior
# prior --amod--> warrior
# movi --compound--> warrior
# chani --nmod--> fremen
# young --compound--> fremen
# fremen --compound--> warrior
# warrior --ccomp--> find
# welcom --compound--> camp
# paul --compound--> camp
# atreid --compound--> camp
# camp --nsubj--> fall
# fall --ccomp--> warrior
# hous --amod--> mother
# rebecca --compound--> ferguson
# ferguson --compound--> ladi
# ladi --compound--> mother
# jessica --compound--> mother
# paul --compound--> mother
# mother --compound--> mother
# becom --compound--> reverend
# reverend --compound--> mother
# mother --nsubj--> fremen
# fremen --ccomp--> find
# believ --compound--> instrument
# paul --compound--> instrument
# instrument --nmod--> child
# propheci --advmod--> instrument
# mother --compound--> child
# child --nsubj--> send
# send --ccomp--> fremen
# reclaim --compound--> coloni
# planet --compound--> arraki
# arraki --compound--> oppress
# oppress --compound--> coloni
# imperi --compound--> coloni
# spicemin --compound--> coloni
# coloni --dobj--> send
# belong --ccomp--> find
# vile --amod--> note
# harkonnen --compound--> note
# famili --compound--> note
# note --nsubj--> get
# also --advmod--> get
# get --aux--> look
# well --intj--> look
# look --ccomp--> find
# harkonnen --compound--> homeworld
# homeworld --npadvmod--> look
# whose --poss--> sun
# black --amod--> sun
# sun --nsubj--> seem
# seem --relcl--> homeworld
# era --compound--> color
# color --compound--> whitest
# bar --nmod--> whitest
# black --amod--> whitest
# black --amod--> whitest
# whitest --oprd--> seem
# whitethi --compound--> moment
# moment --npadvmod--> seem
# one --nummod--> reason
# mani --compound--> reason
# reason --nsubj--> see
# need --aux--> see
# see --oprd--> seem
# theater --nsubj--> stress
# can --aux--> stress
# not --neg--> stress
# stress --ccomp--> see
# enough --amod--> ride
# sequenc --compound--> thunder
# thunder --compound--> ride
# battl --compound--> ride
# sandworm --compound--> ride
# ride --compound--> leave
# intim --compound--> duel
# final --compound--> duel
# duel --compound--> leave
# leave --nmod--> design
# audienc --compound--> edg
# edg --nmod--> seat
# seat --nmod--> design
# paralyz --amod--> complet
# behold --compound--> complet
# auditorium --compound--> complet
# complet --compound--> music
# music --compound--> sound
# sound --compound--> design
# design --nsubj--> seem
# seem --ccomp--> find
# make --xcomp--> seem
# earth --compound--> trembl
# trembl --nsubj--> fall
# fall --ccomp--> make
# dead --amod--> moment
# silent --amod--> moment
# pivot --compound--> moment
# moment --npadvmod--> fall
# sublim --advcl--> seem
# photograph --compound--> swirli
# swirli --dobj--> sublim
# bokeh --amod--> fraser
# extraordinair --compound--> fraser
# greig --compound--> fraser
# fraser --nsubj--> see
# often --advmod--> see
# see --conj--> seem
# film --nsubj--> know
# know --ccomp--> see
# your --poss--> icon
# wit --compound--> icon
# creation --compound--> icon
# icon --nsubj--> impress
# imag --amod--> scene
# action --compound--> scene
# scene --nsubj--> impress
# elev --appos--> scene
# impress --ccomp--> know
# choreographi --nmod--> performancesth
# cour --compound--> performancesth
# performancesth --nsubj--> inten
# inten --ccomp--> impress
# new --amod--> face
# face --dobj--> inten
# undoubtedli --npadvmod--> inten
# austin --compound--> butler
# butler --compound--> feyd
# feyd --nsubj--> rautha
# rautha --conj--> impress
# that --mark--> refer
# sting --amod--> case
# charact --compound--> movi
# movi --compound--> case
# case --nsubj--> refer
# need --aux--> refer
# refer --ccomp--> rautha
# laud --amod--> perform
# mani --nmod--> perform
# good --amod--> perform
# villain --compound--> perform
# perform --compound--> joker
# sinc --compound--> chigurh
# anton --compound--> chigurh
# chigurh --compound--> joker
# ledger --compound--> joker
# joker --compound--> addit
# addit --compound--> newcom
# newcom --compound--> florenc
# includ --compound--> florenc
# florenc --nsubj--> pugh
# pugh --dative--> refer
# princess --nmod--> bene
# irulan --nmod--> bene
# la --det--> bene
# seydoux --amod--> ladi
# ladi --nmod--> bene
# fenr --compound--> bene
# bene --nsubj--> gesseret
# gesseret --conj--> rautha
# priestess --compound--> christoph
# christoph --compound--> emperor
# walken --compound--> emperor
# emperor --compound--> actor
# shaddam --compound--> actor
# ivreturn --compound--> actor
# actor --compound--> leader
# includ --compound--> leader
# javier --compound--> leader
# bardem --compound--> leader
# fremen --compound--> leader
# leader --nsubj--> stilgar
# stilgar --ccomp--> gesseret
# whose --poss--> fanatic
# incorrig --compound--> fanatic
# fanatic --nsubj--> get
# get --advcl--> rautha
# big --amod--> halleck
# laugh --nmod--> halleck
# josh --compound--> halleck
# brolin --compound--> halleck
# gurney --compound--> halleck
# halleck --compound--> baron
# harkonnen --compound--> blood
# blood --compound--> skarsgrd
# stellan --compound--> skarsgrd
# skarsgrd --compound--> baron
# revolt --compound--> baron
# baron --ROOT--> baron
# harkonnen --compound--> bautista
# dave --compound--> bautista
# bautista --compound--> beast
# beast --compound--> envi
# rabban --compound--> envi
# envi --nsubj--> affect
# affect --ROOT--> affect
# baron --compound--> show
# show --dobj--> affect
# toward --prep--> show
# feyd --compound--> rampl
# charlott --compound--> rampl
# rampl --nmod--> scheme
# imperi --compound--> reverend
# reverend --compound--> mother
# mother --compound--> hatch
# hatch --compound--> scheme
# scheme --pobj--> toward
# certain --amod--> charact
# charact --npadvmod--> affect
# I --nsubj--> mention
# have --aux--> mention
# mention --relcl--> charact
# give --advcl--> affect
# minut --compound--> screen
# screen --compound--> time
# time --dobj--> give
# yet --advmod--> give
# make --conj--> give
# consider --compound--> impact
# impact --compound--> line
# memor --compound--> line
# line --nsubj--> read
# read --compound--> look
# look --nsubj--> speak
# speak --ccomp--> make
# even --advmod--> louder
# louder --advmod--> notabl
# notabl --amod--> glanc
# final --amod--> glanc
# exchang --compound--> glanc
# haunt --compound--> glanc
# glanc --compound--> chani
# paul --compound--> chani
# chani --dobj--> speak
# princessat --mark--> perform
# center --compound--> chalamet
# chalamet --compound--> muaddib
# paul --compound--> muaddib
# muaddib --nsubj--> perform
# atreid --nsubj--> perform
# perform --advcl--> affect
# vindic --amod--> stan
# stan --dobj--> perform
# make --advcl--> affect
# nonbeliev --nsubj--> hope
# hope --ccomp--> make
# realiz --compound--> truli
# formid --compound--> truli
# truli --nsubj--> go
# go --ccomp--> make
# part --npadvmod--> go
# one --nummod--> chalamet
# chalamet --nsubj--> know
# know --parataxis--> go
# thin --amod--> frame
# frame --nsubj--> friendli
# friendli --compound--> demeanor
# demeanor --nsubj--> absolut
# yet --advmod--> absolut
# absolut --conj--> affect
# troubl --compound--> paul
# believ --compound--> paul
# paul --nsubj--> master
# would --aux--> master
# master --ccomp--> absolut
# spar --compound--> conqueror
# conqueror --compound--> sandworm
# sandworm --dobj--> master
# write --conj--> affect
# early --amod--> judg
# judg --dobj--> write
# first --amod--> movi
# movi --npadvmod--> affect
# well --intj--> work
# stori --compound--> work
# work --ROOT--> work
# gardenvarieti --compound--> hero
# hero --compound--> bind
# journey --compound--> bind
# bind --punct--> work
# oh --intj--> moment
# moment --npadvmod--> twoif
# twoif --nsubj--> seem
# your --poss--> element
# still --compound--> element
# worri --compound--> element
# element --dobj--> twoif
# seem --ROOT--> seem
# lift --compound--> work
# work --compound--> dune
# recal --amod--> dune
# dune --nsubj--> think
# like --prep--> dune
# old --amod--> whatev
# seri --amod--> whatev
# whatev --pobj--> like
# your --poss--> think
# think --oprd--> seem
# even --advmod--> familiar
# familiar --amod--> imag
# imag --nsubj--> feel
# feel --ccomp--> think
# new --amod--> cinema
# epic --amod--> scale
# scale --compound--> cinema
# way --compound--> cinema
# cinema --nsubj--> abl
# have --aux--> abl
# not --neg--> abl
# abl --ccomp--> feel
# achiev --compound--> movi
# movi --compound--> closetoperfect
# closetoperfect --compound--> hitherto
# marriag --compound--> hitherto
# hitherto --nsubj--> unthink
# unthink --ccomp--> abl
# technolog --compound--> crystalclear
# crystalclear --compound--> vision
# vision --nsubj--> say
# say --ccomp--> feel
# tech --compound--> realiz
# realiz --compound--> movi
# part --compound--> movi
# movi --nsubj--> play
# play --ccomp--> say
# villeneuv --dobj--> play
# hear --advcl--> seem
# complaint --compound--> previou
# previou --compound--> film
# film --dobj--> hear
# dare --aux--> go
# go --conj--> seem
# way --advmod--> put
# movi --nmod--> sequel
# magic --amod--> sequel
# sequel --nsubj--> put
# put --advcl--> go
# doubter --compound--> book
# placeknow --compound--> book
# book --dobj--> put
# go --advcl--> go
# know --advcl--> go
# franchis --nsubj--> do
# far --advmod--> do
# do --advcl--> seem
# despit --nsubj--> want
# long --amod--> film
# film --nsubj--> want
# never --neg--> want
# want --ccomp--> do
# end --nsubj--> crave
# still --advmod--> crave
# crave --ccomp--> want
# ergo --dobj--> crave
# I --nsubj--> be
# be --conj--> seem
# stoke --attr--> be
# see --oprd--> seem
# villeneuv --det--> audienc
# rest --compound--> herbert
# herbert --compound--> audienc
# legendarium --compound--> audienc
# audienc --nsubj--> keep
# keep --ccomp--> see
# find --xcomp--> keep
# reson --amod--> world
# version --compound--> world
# world --nmod--> immen
# dune --nmod--> uniqu
# uniqu --appos--> world
# wellreal --amod--> potenti
# potenti --compound--> intimidatingli
# futur --compound--> intimidatingli
# intimidatingli --compound--> immen
# immen --nsubj--> outlandish
# outlandish --nsubj--> show
# one --nummod--> hand
# hand --compound--> convinc
# dread --compound--> convinc
# convinc --nsubj--> show
# show --ccomp--> find
# imperi --compound--> coloni
# coloni --dobj--> show
# may --aux--> aliv
# aliv --nsubj--> make
# well --advmod--> aliv
# millennia --conj--> aliv
# ahead --advmod--> aliv
# film --dobj--> aliv
# make --ccomp--> see
# even --advmod--> less
# less --amod--> studio
# studio --nsubj--> interfer
# interfer --ccomp--> make
# parallel --amod--> fremen
# fremen --compound--> palestin
# plight --compound--> palestin
# palestin --dobj--> interfer
# may --aux--> stori
# even --advmod--> stori
# obviousth --compound--> stori
# stori --compound--> messiah
# dune --compound--> messiah
# messiah --nsubj--> need
# still --advmod--> need
# need --conj--> make
# adapt --dobj--> need
# I --nsubj--> be
# be --ccomp--> make
# confid --acomp--> be
# villeneuv --advmod--> show
# show --nsubj--> take
# we --dobj--> show
# medium --amod--> illiter
# illiter --compound--> twitter
# start --compound--> twitter
# post --compound--> twitter
# film --compound--> twitter
# twitter --nsubj--> take
# take --ccomp--> show
# poor --amod--> thing
# thing --dobj--> take
# approv --compound--> misogyni
# misogyni --compound--> film
# film --compound--> digit
# come --compound--> digit
# digit --npadvmod--> take
# will --aux--> take
# not --neg--> take
# take --ROOT--> take
# paul --nmod--> savior
# white --compound--> savior
# savior --dobj--> take
# jessica --compound--> cultur
# cultur --compound--> face
# appropri --compound--> face
# face --compound--> valu
# valu --nsubj--> hope
# may --aux--> hope
# hope --ccomp--> take
# interest --compound--> chaw
# theori --compound--> chaw
# walter --compound--> chaw
# chaw --nsubj--> suggest
# suggest --ccomp--> hope
# reason --dobj--> suggest
# mani --compound--> peopl
# peopl --compound--> keep
# keep --relcl--> reason
# fail --acl--> reason
# get --xcomp--> fail
# point --compound--> embed
# dune --compound--> paul
# paul --compound--> embed
# atreid --compound--> specif
# specif --compound--> embed
# coloni --compound--> embed
# embed --nsubj--> valu
# valu --ccomp--> get
# system --compound--> manifest
# manifest --compound--> imposs
# destini --compound--> straightup
# straightup --compound--> imposs
# imposs --dobj--> valu
# we --nsubj--> interpret
# interpret --relcl--> imposs
# figur --dobj--> interpret
# like --prep--> get
# anyth --nmod--> guy
# good --amod--> guy
# guy --pobj--> like
# lisan --appos--> guy
# algaib --dobj--> take
#
#
# Sentence 990:
# deni yet understand cinema understand sourc materi take stori elev sourc materi way live alongsid bookdeni intent choo focu stori paul intern battl forc propheci devot someon face dutyth movi clearli spectacl watch movi also upfront theme book appreci deni know chang stori help elev themesi read book qualm chang make storyi applaud deni
#
# Constituency Parse Tree:
# (S
#   deni/NN
#   yet/RB
#   understand/JJ
#   cinema/NN
#   understand/NN
#   sourc/NN
#   materi/NNS
#   take/VBP
#   stori/JJ
#   elev/NN
#   sourc/NN
#   materi/JJ
#   way/NN
#   live/JJ
#   alongsid/NN
#   bookdeni/NN
#   intent/NN
#   choo/NN
#   focu/NN
#   stori/NN
#   paul/NN
#   intern/JJ
#   battl/NN
#   forc/NN
#   propheci/NN
#   devot/NN
#   someon/NN
#   face/NN
#   dutyth/NN
#   movi/NN
#   clearli/NN
#   spectacl/NN
#   watch/NN
#   movi/NN
#   also/RB
#   upfront/JJ
#   theme/NN
#   book/NN
#   appreci/JJ
#   deni/NN
#   know/VBP
#   chang/NN
#   stori/NN
#   help/NN
#   elev/VB
#   themesi/JJ
#   read/JJ
#   book/NN
#   qualm/NN
#   chang/NNS
#   make/VBP
#   storyi/JJ
#   applaud/NN
#   deni/NN)
#
# Dependency Parse:
# deni --nsubj--> understand
# yet --advmod--> understand
# understand --ROOT--> understand
# cinema --nsubj--> understand
# understand --ccomp--> understand
# sourc --compound--> materi
# materi --nmod--> stori
# take --compound--> stori
# stori --dobj--> understand
# elev --amod--> way
# sourc --nmod--> way
# materi --amod--> way
# way --npadvmod--> live
# live --amod--> intent
# alongsid --amod--> bookdeni
# bookdeni --compound--> intent
# intent --ccomp--> understand
# choo --compound--> stori
# focu --compound--> stori
# stori --nmod--> forc
# paul --compound--> intern
# intern --nmod--> forc
# battl --compound--> forc
# forc --appos--> intent
# propheci --advmod--> someon
# devot --compound--> someon
# someon --nsubj--> face
# face --ccomp--> understand
# dutyth --compound--> movi
# movi --compound--> movi
# clearli --compound--> spectacl
# spectacl --compound--> watch
# watch --compound--> movi
# movi --dobj--> face
# also --advmod--> upfront
# upfront --dep--> understand
# theme --compound--> book
# book --dobj--> upfront
# appreci --appos--> book
# deni --nsubj--> know
# know --ccomp--> understand
# chang --compound--> stori
# stori --nsubj--> help
# help --ccomp--> know
# elev --amod--> chang
# themesi --npadvmod--> read
# read --compound--> book
# book --compound--> chang
# qualm --compound--> chang
# chang --nsubj--> make
# make --ccomp--> help
# storyi --compound--> applaud
# applaud --compound--> deni
# deni --dobj--> make
#
#
# Sentence 991:
# ill tri keep simpl sothi exact type movi go see big screen liter jaw dropag scale feel massiv make feel tini mani scene blow away effect damn brilliant stun visual ever abl see movi act entir cast complet top shelf special shoutout austin butler feydrautha perfect score oooft tap foot time also swear point could smell sand that immer movieaft watch coupl low budget type scifi movi late slightli differ scifi genr like synchron freak enjoy lot go watch dune part think yeahhhhh whole level think see budget new gladiat million dune part million look unbeliev amaz budget make think hell gladiat money read book love I have see part love scene part movi much well imagin book scifi lover do not like movi ill shock absolut epic genr think hard top anytim soon everyon need see big screen lose planet dunedeni villeneuv nail might favourit creator industri moment nolan tone style extract unreal crave cinema moment hope lot come
#
# Constituency Parse Tree:
# (S
#   ill/NN
#   tri/VBZ
#   keep/VB
#   simpl/NN
#   sothi/NN
#   exact/JJ
#   type/NN
#   movi/NN
#   go/VBP
#   see/VB
#   big/JJ
#   screen/NN
#   liter/NN
#   jaw/NN
#   dropag/NN
#   scale/NN
#   feel/NN
#   massiv/NNS
#   make/VBP
#   feel/VB
#   tini/JJ
#   mani/NNS
#   scene/VBP
#   blow/VB
#   away/RP
#   effect/NN
#   damn/NN
#   brilliant/JJ
#   stun/NN
#   visual/JJ
#   ever/RB
#   abl/VBP
#   see/VB
#   movi/JJ
#   act/NN
#   entir/IN
#   cast/JJ
#   complet/NN
#   top/VB
#   shelf/NN
#   special/JJ
#   shoutout/NN
#   austin/NN
#   butler/NN
#   feydrautha/NN
#   perfect/JJ
#   score/NN
#   oooft/JJ
#   tap/JJ
#   foot/NN
#   time/NN
#   also/RB
#   swear/JJ
#   point/NN
#   could/MD
#   smell/VB
#   sand/NN
#   that/IN
#   immer/JJ
#   movieaft/NN
#   watch/NN
#   coupl/NN
#   low/JJ
#   budget/NN
#   type/NN
#   scifi/NN
#   movi/NN
#   late/JJ
#   slightli/NN
#   differ/NN
#   scifi/JJ
#   genr/NN
#   like/IN
#   synchron/NN
#   freak/NN
#   enjoy/NN
#   lot/NN
#   go/VBP
#   watch/NN
#   dune/NN
#   part/NN
#   think/VBP
#   yeahhhhh/JJ
#   whole/JJ
#   level/NN
#   think/VBP
#   see/VB
#   budget/NN
#   new/JJ
#   gladiat/NN
#   million/CD
#   dune/JJ
#   part/NN
#   million/CD
#   look/NN
#   unbeliev/JJ
#   amaz/NN
#   budget/NN
#   make/VBP
#   think/NN
#   hell/NN
#   gladiat/VBZ
#   money/NN
#   read/VBN
#   book/NN
#   love/NN
#   I/PRP
#   have/VBP
#   see/VBN
#   part/NN
#   love/VB
#   scene/NN
#   part/NN
#   movi/NN
#   much/RB
#   well/RB
#   imagin/VB
#   book/NN
#   scifi/NN
#   lover/RB
#   do/VBP
#   not/RB
#   like/IN
#   movi/NNS
#   ill/VBP
#   shock/NN
#   absolut/NN
#   epic/VBP
#   genr/NN
#   think/VBP
#   hard/JJ
#   top/JJ
#   anytim/NN
#   soon/RB
#   everyon/VBD
#   need/MD
#   see/VB
#   big/JJ
#   screen/NN
#   lose/JJ
#   planet/NN
#   dunedeni/NN
#   villeneuv/NN
#   nail/NN
#   might/MD
#   favourit/VB
#   creator/NN
#   industri/JJ
#   moment/NN
#   nolan/NN
#   tone/NN
#   style/NN
#   extract/JJ
#   unreal/JJ
#   crave/NN
#   cinema/NN
#   moment/NN
#   hope/NN
#   lot/NN
#   come/VB)
#
# Dependency Parse:
# ill --compound--> tri
# tri --nsubj--> keep
# keep --ccomp--> think
# simpl --compound--> sothi
# sothi --compound--> movi
# exact --amod--> type
# type --compound--> movi
# movi --nsubj--> go
# go --ccomp--> keep
# see --advcl--> go
# big --amod--> liter
# screen --compound--> liter
# liter --compound--> scale
# jaw --compound--> scale
# dropag --compound--> scale
# scale --nsubj--> feel
# feel --ccomp--> see
# massiv --nsubj--> make
# make --ccomp--> feel
# feel --ccomp--> make
# tini --amod--> scene
# mani --compound--> scene
# scene --nsubj--> blow
# blow --conj--> keep
# away --advmod--> blow
# effect --compound--> visual
# damn --advmod--> brilliant
# brilliant --amod--> visual
# stun --compound--> visual
# visual --nsubj--> see
# ever --advmod--> abl
# abl --advmod--> see
# see --advcl--> blow
# movi --compound--> act
# act --nsubj--> entir
# entir --nmod--> score
# cast --compound--> complet
# complet --dobj--> entir
# top --amod--> shoutout
# shelf --nmod--> shoutout
# special --amod--> shoutout
# shoutout --appos--> complet
# austin --compound--> butler
# butler --nmod--> feydrautha
# feydrautha --npadvmod--> perfect
# perfect --amod--> score
# score --compound--> time
# oooft --amod--> foot
# tap --compound--> foot
# foot --compound--> time
# time --nsubj--> swear
# also --advmod--> swear
# swear --ccomp--> see
# point --nsubj--> smell
# could --aux--> smell
# smell --ccomp--> swear
# sand --dobj--> smell
# that --mark--> watch
# immer --compound--> movieaft
# movieaft --nsubj--> watch
# watch --ccomp--> smell
# coupl --nmod--> movi
# low --compound--> budget
# budget --compound--> type
# type --compound--> movi
# scifi --compound--> movi
# movi --nsubj--> differ
# late --compound--> slightli
# slightli --nsubj--> differ
# differ --conj--> keep
# scifi --compound--> genr
# genr --dobj--> differ
# like --prep--> genr
# synchron --compound--> freak
# freak --compound--> lot
# enjoy --compound--> lot
# lot --pobj--> like
# go --conj--> keep
# watch --compound--> part
# dune --amod--> part
# part --nsubj--> think
# think --ROOT--> think
# yeahhhhh --amod--> level
# whole --amod--> level
# level --nsubj--> think
# think --ccomp--> think
# see --xcomp--> think
# budget --compound--> million
# new --amod--> million
# gladiat --compound--> million
# million --compound--> million
# dune --compound--> million
# part --compound--> million
# million --nsubj--> look
# look --dep--> make
# unbeliev --acomp--> look
# amaz --prep--> look
# budget --pobj--> amaz
# make --dobj--> see
# think --ccomp--> make
# hell --nsubj--> gladiat
# gladiat --nsubj--> read
# money --dobj--> gladiat
# read --ccomp--> think
# book --compound--> love
# love --dobj--> read
# I --nsubj--> see
# have --aux--> see
# see --relcl--> love
# part --compound--> scene
# love --compound--> scene
# scene --compound--> movi
# part --compound--> movi
# movi --ccomp--> think
# much --advmod--> well
# well --advmod--> think
# imagin --compound--> lover
# book --compound--> scifi
# scifi --compound--> lover
# lover --nsubj--> like
# do --aux--> like
# not --neg--> like
# like --ccomp--> think
# movi --compound--> absolut
# ill --amod--> absolut
# shock --compound--> absolut
# absolut --dobj--> like
# epic --compound--> genr
# genr --nsubj--> think
# think --ccomp--> think
# hard --amod--> top
# top --compound--> anytim
# anytim --nsubj--> everyon
# soon --advmod--> everyon
# everyon --ccomp--> think
# need --nsubj--> see
# see --ccomp--> think
# big --amod--> screen
# screen --nsubj--> lose
# lose --ccomp--> see
# planet --compound--> nail
# dunedeni --compound--> villeneuv
# villeneuv --compound--> nail
# nail --dobj--> lose
# might --aux--> favourit
# favourit --compound--> creator
# creator --nmod--> style
# industri --amod--> moment
# moment --compound--> style
# nolan --compound--> tone
# tone --compound--> style
# style --nsubj--> extract
# extract --ccomp--> see
# unreal --amod--> moment
# crave --compound--> cinema
# cinema --compound--> moment
# moment --compound--> hope
# hope --compound--> lot
# lot --nsubj--> come
# come --ccomp--> see
#
#
# Sentence 992:
# everyth movi good practic make numb still can not even process I be huge fan novel way movi manag improv sourc materi give we intim rendit awesom storyit total kick ass front write visual sound designmus act absolut high level grand scale truli epic one good adapt novel screen ever make easi task either give film sourc materi execut tast dare say flawlessli util minor alter creat good film believ hype do not like movi well guess epic scifi stori desert simpli be not thing fair enough us realli do not get well thisth script excel hard novel adapt writer truli do fantast job chang make sourc materi detail ad essenti captur good theme book overal chang cut addit make well movi still remain faith film sourc materi admit howev dune nerd would like see talk babi way effect probabl well silver screen frank herbert purist might get pretti bum chang work well trust deni villeneuv want tellingi want point kind surpris terrif act film consid amount vaniti celebr cast seem bask be not cast marilyn manson would call beauti peopl actual talent one timothi chalamet realli bring film second half bear play paul atreid would never know capabl pull well previous see love austin butler feydrautha actual javier bardem stilgar enjoy charact beauti write screenplay provid smart laugh loud comic relief also deliv seriou dramat scene awesom dialogu deliveri do not care believ believ perfectli place trailer even well film man good actor obvious give track record simpli awesom see deliv well write dialogueth visual fx do not even know convey great look simpli put stun treat see imax movi truli make imax look incrediblewhich bring cinematographi also stun absolut perfect light color pallet god stunningsound design score everi bit awesom first film perfect han zimmer realli prime career give we stunningli origin memor work musica far memor scene sequenc go everi singl one hit pretti hard expertli craft climat final knife fight good scene sinc climat sword fight rob roy can not write gush review without mention sandworm ride scene paul first mount one icon beast wow goe one favorit scene ever film practic edg seat even know outcom would read book wow coolupon movi end wife want stay theater watch can not wait see film realli think modern classic be not someth say lightli hype real hope feel dune dune part great time I have movi past twenti year larg budget major studio film art grandest scale cheap attempt cash belov franchis refresh nice see hollywood still qualiti film make person opinion timothi chalamet zendaya earn everi right wear ludicr outfit red carpet could worn hot dog suit care fantast job entir cast crew film help creat someth peopl enjoy long time
#
# Constituency Parse Tree:
# (S
#   everyth/NN
#   movi/NN
#   good/JJ
#   practic/JJ
#   make/NN
#   numb/NN
#   still/RB
#   can/MD
#   not/RB
#   even/RB
#   process/VB
#   I/PRP
#   be/VB
#   huge/JJ
#   fan/NN
#   novel/JJ
#   way/NN
#   movi/NN
#   manag/NN
#   improv/NN
#   sourc/NN
#   materi/RBS
#   give/VBP
#   we/PRP
#   intim/VBP
#   rendit/JJ
#   awesom/NN
#   storyit/JJ
#   total/JJ
#   kick/NN
#   ass/NN
#   front/NN
#   write/VBP
#   visual/JJ
#   sound/NN
#   designmus/NN
#   act/NN
#   absolut/RB
#   high/JJ
#   level/NN
#   grand/JJ
#   scale/NN
#   truli/NN
#   epic/IN
#   one/CD
#   good/JJ
#   adapt/NN
#   novel/NN
#   screen/NN
#   ever/RB
#   make/VB
#   easi/NN
#   task/NN
#   either/CC
#   give/VB
#   film/NN
#   sourc/NN
#   materi/NN
#   execut/VBD
#   tast/JJ
#   dare/NN
#   say/VBP
#   flawlessli/NN
#   util/JJ
#   minor/JJ
#   alter/NN
#   creat/NN
#   good/JJ
#   film/NN
#   believ/NN
#   hype/NN
#   do/VBP
#   not/RB
#   like/IN
#   movi/NNS
#   well/RB
#   guess/RB
#   epic/JJ
#   scifi/NN
#   stori/NN
#   desert/NN
#   simpli/NN
#   be/VB
#   not/RB
#   thing/NN
#   fair/JJ
#   enough/RB
#   us/PRP
#   realli/VB
#   do/VBP
#   not/RB
#   get/VB
#   well/RB
#   thisth/JJ
#   script/NN
#   excel/RB
#   hard/JJ
#   novel/NN
#   adapt/JJ
#   writer/NN
#   truli/NNS
#   do/VBP
#   fantast/RB
#   job/NN
#   chang/NNS
#   make/VBP
#   sourc/JJ
#   materi/NN
#   detail/NN
#   ad/NN
#   essenti/NN
#   captur/NN
#   good/JJ
#   theme/NN
#   book/NN
#   overal/JJ
#   chang/NN
#   cut/NN
#   addit/NN
#   make/VBP
#   well/RB
#   movi/VB
#   still/RB
#   remain/VBP
#   faith/JJ
#   film/NN
#   sourc/NN
#   materi/NN
#   admit/NN
#   howev/NN
#   dune/NN
#   nerd/RB
#   would/MD
#   like/VB
#   see/VB
#   talk/NN
#   babi/IN
#   way/NN
#   effect/NN
#   probabl/NN
#   well/RB
#   silver/RB
#   screen/JJ
#   frank/NN
#   herbert/JJ
#   purist/NN
#   might/MD
#   get/VB
#   pretti/JJ
#   bum/NN
#   chang/NN
#   work/NN
#   well/RB
#   trust/RB
#   deni/JJ
#   villeneuv/NN
#   want/VBP
#   tellingi/NN
#   want/VBP
#   point/NN
#   kind/NN
#   surpris/JJ
#   terrif/NN
#   act/NN
#   film/NN
#   consid/NN
#   amount/NN
#   vaniti/FW
#   celebr/NN
#   cast/NN
#   seem/VBP
#   bask/RB
#   be/VB
#   not/RB
#   cast/JJ
#   marilyn/NN
#   manson/NN
#   would/MD
#   call/VB
#   beauti/NN
#   peopl/NN
#   actual/JJ
#   talent/NN
#   one/CD
#   timothi/NN
#   chalamet/NN
#   realli/NN
#   bring/NN
#   film/NN
#   second/JJ
#   half/NN
#   bear/JJ
#   play/NN
# ...
#
# Constituency Parse Tree:
# (S
#   masterpiec/VB
#   cour/NN
#   wor/NN
#   film/NN
#   do/VBP
#   not/RB
#   get/VB
#   other/JJ
#   see/VB
#   two/CD
#   film/NN
#   hour/NN
#   storylin/NN
#   poorli/NN
#   develop/VB
#   world/NN
#   still/RB
#   realli/VBZ
#   explain/VB
#   there/EX
#   depth/RB
#   much/JJ
#   lot/NN
#   sand/NN
#   religi/NN
#   sort/NN
#   nonsens/VBZ
#   blue/JJ
#   water/NN
#   sand/NN
#   propheci/NN
#   bang/NN
#   averag/JJ
#   action/NN
#   load/NN
#   plot/NN
#   hole/NN
#   big/JJ
#   worm/NN
#   hope/VBP
#   part/NN
#   make/VBP
#   part/NN
#   make/VBP
#   sen/VBN
#   instead/RB
#   I/PRP
#   have/VBP
#   got/VBN
#   even/RB
#   question/NN
#   that/IN
#   failur/NN
#   screen/NN
#   play/VB
#   hour/NN
#   either/CC
#   conclud/NN
#   plot/NN
#   line/NN
#   conclud/NN
#   open/JJ
#   enough/RB
#   want/VBP
#   see/JJ
#   end/VBP
#   feel/NN
#   I/PRP
#   have/VBP
#   wast/VBN
#   hour/NN
#   want/VBP
#   see/NN
#   fuss/NN
#   still/RB
#   do/VBP
#   not/RB
#   get/VB)
#
# Dependency Parse:
# masterpiec --nsubj--> get
# cour --compound--> film
# wor --compound--> film
# film --appos--> masterpiec
# do --aux--> get
# not --neg--> get
# get --ccomp--> explain
# other --acomp--> get
# see --dep--> get
# two --nummod--> poorli
# film --compound--> hour
# hour --compound--> poorli
# storylin --compound--> poorli
# poorli --nsubj--> develop
# develop --ccomp--> see
# world --dobj--> develop
# still --advmod--> realli
# realli --nsubj--> explain
# explain --ROOT--> explain
# there --expl--> depth
# depth --ccomp--> explain
# much --amod--> lot
# lot --compound--> sort
# sand --compound--> sort
# religi --compound--> sort
# sort --nmod--> hole
# nonsens --nmod--> hole
# blue --amod--> water
# water --compound--> sand
# sand --nmod--> hole
# propheci --advmod--> sand
# bang --compound--> action
# averag --compound--> action
# action --compound--> load
# load --compound--> hole
# plot --compound--> hole
# hole --dobj--> depth
# big --compound--> worm
# worm --appos--> hole
# hope --ccomp--> explain
# part --nsubj--> make
# make --ccomp--> hope
# part --nsubj--> make
# make --ccomp--> make
# sen --ccomp--> make
# instead --advmod--> got
# I --nsubj--> got
# have --aux--> got
# got --aux--> question
# even --advmod--> question
# question --conj--> explain
# that --mark--> open
# failur --compound--> screen
# screen --compound--> hour
# play --compound--> hour
# hour --npadvmod--> open
# either --preconj--> conclud
# conclud --compound--> line
# plot --compound--> line
# line --compound--> conclud
# conclud --nsubj--> open
# open --ccomp--> question
# enough --advmod--> open
# want --advcl--> explain
# see --xcomp--> want
# end --nsubj--> feel
# feel --ccomp--> see
# I --nsubj--> have
# have --ccomp--> feel
# wast --compound--> hour
# hour --npadvmod--> want
# want --ccomp--> explain
# see --xcomp--> want
# fuss --nsubj--> get
# still --advmod--> get
# do --aux--> get
# not --neg--> get
# get --ccomp--> see
#
#
# Sentence 999:
# good movieth stori pick basic right first movi plot get deeply deeply throughout movi give gener gistpaul battl fact propheci mother goe beyond prove chani paul grow close time becom fremen vow stick remain isbeast struggl fremen attack stop spice harvest brother feyd bring psychopath need someon crazi elimin threatth whole movi religi power struggl battl north south contrast seek leader strong movi senseth act top notch everyon timothe realli movi second half show chop wow one strong perform opinionit hard pick other strong mother play viciou role superbl austin butler great craze killer power hungri lunat greatth score visual go without say cinema experi need onei give first low score be not great
#
# Constituency Parse Tree:
# (S
#   good/JJ
#   movieth/NNS
#   stori/VBP
#   pick/JJ
#   basic/JJ
#   right/NN
#   first/RB
#   movi/VBZ
#   plot/NN
#   get/VB
#   deeply/RB
#   deeply/RB
#   throughout/IN
#   movi/NNS
#   give/VBP
#   gener/NN
#   gistpaul/NN
#   battl/NN
#   fact/NN
#   propheci/IN
#   mother/NN
#   goe/NN
#   beyond/IN
#   prove/JJ
#   chani/NN
#   paul/NN
#   grow/VB
#   close/JJ
#   time/NN
#   becom/NN
#   fremen/NNS
#   vow/VBP
#   stick/JJ
#   remain/VBP
#   isbeast/JJ
#   struggl/JJ
#   fremen/NNS
#   attack/VBP
#   stop/JJ
#   spice/NN
#   harvest/NN
#   brother/NN
#   feyd/NN
#   bring/VBG
#   psychopath/NN
#   need/NN
#   someon/NN
#   crazi/VB
#   elimin/JJ
#   threatth/JJ
#   whole/JJ
#   movi/NN
#   religi/NN
#   power/NN
#   struggl/NN
#   battl/VBD
#   north/JJ
#   south/JJ
#   contrast/NN
#   seek/JJ
#   leader/NN
#   strong/JJ
#   movi/NN
#   senseth/NN
#   act/NN
#   top/JJ
#   notch/NN
#   everyon/NN
#   timothe/NN
#   realli/NN
#   movi/VBD
#   second/JJ
#   half/NN
#   show/NN
#   chop/NN
#   wow/VBP
#   one/CD
#   strong/JJ
#   perform/NN
#   opinionit/RB
#   hard/JJ
#   pick/NN
#   other/JJ
#   strong/JJ
#   mother/NN
#   play/NN
#   viciou/FW
#   role/NN
#   superbl/NN
#   austin/JJ
#   butler/NN
#   great/JJ
#   craze/NN
#   killer/NN
#   power/NN
#   hungri/NN
#   lunat/NN
#   greatth/NN
#   score/NN
#   visual/JJ
#   go/NN
#   without/IN
#   say/VBP
#   cinema/NN
#   experi/NNS
#   need/VBP
#   onei/RB
#   give/VBP
#   first/RB
#   low/JJ
#   score/RB
#   be/VB
#   not/RB
#   great/JJ)
#
# Dependency Parse:
# good --amod--> stori
# movieth --compound--> stori
# stori --nsubj--> pick
# pick --ROOT--> pick
# basic --amod--> plot
# right --advmod--> first
# first --amod--> plot
# movi --compound--> plot
# plot --dobj--> pick
# get --conj--> pick
# deeply --advmod--> deeply
# deeply --advmod--> get
# throughout --prep--> get
# movi --pobj--> throughout
# give --advcl--> pick
# gener --compound--> gistpaul
# gistpaul --compound--> fact
# battl --compound--> fact
# fact --dative--> give
# propheci --advmod--> fact
# mother --compound--> goe
# goe --ccomp--> give
# beyond --prep--> grow
# prove --pobj--> beyond
# chani --compound--> paul
# paul --nsubj--> grow
# grow --advcl--> goe
# close --amod--> time
# time --compound--> stick
# becom --compound--> fremen
# fremen --compound--> stick
# vow --compound--> stick
# stick --nsubj--> remain
# remain --ccomp--> grow
# isbeast --compound--> struggl
# struggl --compound--> stop
# fremen --compound--> stop
# attack --compound--> stop
# stop --compound--> harvest
# spice --compound--> harvest
# harvest --compound--> brother
# brother --compound--> feyd
# feyd --nsubj--> bring
# bring --conj--> grow
# psychopath --dobj--> bring
# need --compound--> threatth
# someon --compound--> crazi
# crazi --compound--> elimin
# elimin --nsubj--> threatth
# threatth --advcl--> bring
# whole --amod--> movi
# movi --compound--> battl
# religi --compound--> power
# power --compound--> struggl
# struggl --compound--> battl
# battl --compound--> contrast
# north --compound--> south
# south --amod--> contrast
# contrast --dobj--> threatth
# seek --conj--> pick
# leader --compound--> movi
# strong --amod--> movi
# movi --dobj--> seek
# senseth --compound--> act
# act --conj--> pick
# top --compound--> notch
# notch --dobj--> act
# everyon --conj--> pick
# timothe --det--> movi
# realli --compound--> movi
# movi --dobj--> everyon
# second --amod--> half
# half --npadvmod--> pick
# show --compound--> chop
# chop --dobj--> pick
# wow --intj--> perform
# one --nummod--> wow
# strong --amod--> one
# perform --nsubj--> pick
# opinionit --advmod--> perform
# hard --advmod--> pick
# pick --nsubj--> hungri
# other --amod--> mother
# strong --amod--> mother
# mother --dobj--> pick
# play --conj--> pick
# viciou --compound--> role
# role --dobj--> play
# superbl --nmod--> power
# austin --nmod--> butler
# butler --nmod--> craze
# great --amod--> craze
# craze --compound--> power
# killer --compound--> power
# power --dobj--> pick
# hungri --nsubj--> go
# lunat --compound--> visual
# greatth --amod--> score
# score --compound--> visual
# visual --nsubj--> go
# go --ROOT--> go
# without --prep--> go
# say --pobj--> without
# cinema --compound--> experi
# experi --compound--> onei
# need --compound--> onei
# onei --nsubj--> give
# give --advcl--> go
# first --amod--> score
# low --amod--> score
# score --nsubj--> be
# be --ccomp--> give
# not --neg--> be
# great --acomp--> be
#
#
# Sentence 1000:
# dune part two intellig blockbust filmmak fine epic tragedi tell big canva imagin everi depart oper unison top game first dune may focus setup do not mean one rush straight action maintain immer slow burn naturetimoth chalamet get nice journey origin howev one much big play intern conflict well tri good avoid destini end feel like differ person entir way do not come nowher early moment also display palpabl chemistri zendaya begin truli connecta well strong chemistri chalamet zendaya give much promis essenti becom colead film descend climact moment remain one who abl see manipul that happen fair moment look frustrat say everythingther mani huge name cast do not get much impact way fulli commit small part austin butler major highlight film describ psychot honestli that put mildli deliber imperson baron realli work make even unsettlingit clear first major action sequenc bath beauti orang hue director deni villeneuv master craft point even compar part one scale chapter immen return cinematograph greig fraser bring specif set skill make undeni cinemat eventconsid good previou score han zimmer couldv easili coast one reus theme obviou would not clearli love play sandbox almost everi transcend piec last time still present there new one equal memor
#
# Constituency Parse Tree:
# (S
#   dune/JJ
#   part/NN
#   two/CD
#   intellig/NN
#   blockbust/NN
#   filmmak/NN
#   fine/JJ
#   epic/NN
#   tragedi/NN
#   tell/VBP
#   big/JJ
#   canva/NN
#   imagin/NN
#   everi/VBP
#   depart/JJ
#   oper/IN
#   unison/JJ
#   top/JJ
#   game/NN
#   first/RB
#   dune/VBZ
#   may/MD
#   focus/VB
#   setup/NNS
#   do/VBP
#   not/RB
#   mean/VB
#   one/CD
#   rush/NN
#   straight/VBN
#   action/NN
#   maintain/NN
#   immer/NN
#   slow/JJ
#   burn/NN
#   naturetimoth/DT
#   chalamet/NN
#   get/VB
#   nice/JJ
#   journey/NN
#   origin/NN
#   howev/VB
#   one/CD
#   much/RB
#   big/JJ
#   play/NN
#   intern/JJ
#   conflict/NN
#   well/RB
#   tri/RB
#   good/JJ
#   avoid/NN
#   destini/JJ
#   end/NN
#   feel/NN
#   like/IN
#   differ/NN
#   person/NN
#   entir/JJ
#   way/NN
#   do/VBP
#   not/RB
#   come/VB
#   nowher/RB
#   early/JJ
#   moment/NN
#   also/RB
#   display/VBP
#   palpabl/JJ
#   chemistri/NN
#   zendaya/NN
#   begin/VBP
#   truli/NNS
#   connecta/VBP
#   well/RB
#   strong/JJ
#   chemistri/NN
#   chalamet/NN
#   zendaya/NN
#   give/VBP
#   much/JJ
#   promis/NN
#   essenti/NN
#   becom/NN
#   colead/NN
#   film/NN
#   descend/VBP
#   climact/NN
#   moment/NN
#   remain/VBP
#   one/CD
#   who/WP
#   abl/VBP
#   see/VBP
#   manipul/NNS
#   that/WDT
#   happen/VBP
#   fair/JJ
#   moment/NN
#   look/NN
#   frustrat/NNS
#   say/VBP
#   everythingther/RB
#   mani/JJ
#   huge/JJ
#   name/NN
#   cast/NN
#   do/VBP
#   not/RB
#   get/VB
#   much/JJ
#   impact/NN
#   way/NN
#   fulli/JJ
#   commit/NN
#   small/JJ
#   part/NN
#   austin/NN
#   butler/NN
#   major/JJ
#   highlight/NN
#   film/NN
#   describ/NN
#   psychot/NN
#   honestli/NN
#   that/WDT
#   put/VBD
#   mildli/RBS
#   deliber/NNP
#   imperson/NN
#   baron/NN
#   realli/NN
#   work/NN
#   make/VBP
#   even/RB
#   unsettlingit/JJ
#   clear/VBP
#   first/JJ
#   major/JJ
#   action/NN
#   sequenc/VBD
#   bath/NN
#   beauti/NN
#   orang/NN
#   hue/NN
#   director/NN
#   deni/NN
#   villeneuv/NN
#   master/NN
#   craft/NN
#   point/NN
#   even/RB
#   compar/VBD
#   part/NN
#   one/CD
#   scale/NN
#   chapter/NN
#   immen/NNS
#   return/VBP
#   cinematograph/JJ
#   greig/NNS
#   fraser/RBR
#   bring/JJ
#   specif/NN
#   set/NN
#   skill/NN
#   make/VBP
#   undeni/JJ
#   cinemat/NN
#   eventconsid/NN
#   good/JJ
#   previou/NN
#   score/NN
#   han/NN
#   zimmer/NN
#   couldv/NN
#   easili/VBD
#   coast/NN
#   one/CD
#   reus/NN
#   theme/NN
#   obviou/NN
#   would/MD
#   not/RB
#   clearli/VB
#   love/VB
#   play/NN
#   sandbox/NN
#   almost/RB
#   everi/JJ
#   transcend/NN
#   piec/NN
#   last/JJ
#   time/NN
#   still/RB
#   present/VB
#   there/RB
#   new/JJ
#   one/CD
#   equal/JJ
#   memor/NN)
#
# Dependency Parse:
# dune --amod--> part
# part --ROOT--> part
# two --nummod--> intellig
# intellig --appos--> part
# blockbust --prep--> part
# filmmak --compound--> fine
# fine --ROOT--> fine
# epic --ROOT--> epic
# tragedi --nsubj--> tell
# tell --ROOT--> tell
# big --amod--> canva
# canva --dobj--> tell
# imagin --nmod--> game
# everi --nmod--> unison
# depart --compound--> oper
# oper --compound--> unison
# unison --nmod--> game
# top --amod--> game
# game --dobj--> tell
# first --amod--> dune
# dune --nsubj--> focus
# may --aux--> focus
# focus --ccomp--> tell
# setup --dobj--> focus
# do --aux--> mean
# not --neg--> mean
# mean --ccomp--> tell
# one --nummod--> rush
# rush --nmod--> action
# straight --amod--> action
# action --nsubj--> maintain
# maintain --ccomp--> mean
# immer --compound--> slow
# slow --nsubj--> burn
# burn --compound--> chalamet
# naturetimoth --amod--> chalamet
# chalamet --nsubj--> get
# get --ccomp--> maintain
# nice --amod--> howev
# journey --compound--> origin
# origin --compound--> howev
# howev --dobj--> get
# one --nummod--> conflict
# much --advmod--> big
# big --amod--> conflict
# play --compound--> conflict
# intern --compound--> conflict
# conflict --nsubj--> feel
# well --dep--> feel
# tri --amod--> end
# good --amod--> end
# avoid --compound--> end
# destini --compound--> end
# end --nsubj--> feel
# feel --relcl--> howev
# like --prep--> feel
# differ --amod--> person
# person --npadvmod--> entir
# entir --amod--> way
# way --pobj--> like
# do --aux--> come
# not --neg--> come
# come --ccomp--> mean
# nowher --advmod--> come
# early --amod--> moment
# moment --nsubj--> display
# also --advmod--> display
# display --ccomp--> tell
# palpabl --compound--> zendaya
# chemistri --compound--> zendaya
# zendaya --dobj--> display
# begin --ccomp--> tell
# truli --compound--> zendaya
# connecta --advmod--> strong
# well --advmod--> strong
# strong --amod--> zendaya
# chemistri --amod--> chalamet
# chalamet --compound--> zendaya
# zendaya --dobj--> begin
# give --ccomp--> tell
# much --amod--> promis
# promis --nmod--> moment
# essenti --compound--> film
# becom --compound--> colead
# colead --compound--> film
# film --compound--> moment
# descend --compound--> moment
# climact --compound--> moment
# moment --nsubj--> remain
# remain --conj--> tell
# one --attr--> remain
# who --nsubj--> see
# abl --advmod--> see
# see --relcl--> one
# manipul --dobj--> see
# that --nsubj--> happen
# happen --relcl--> manipul
# fair --amod--> moment
# moment --compound--> look
# look --ccomp--> see
# frustrat --nsubj--> say
# say --ROOT--> say
# everythingther --compound--> name
# mani --nmod--> name
# huge --amod--> name
# name --compound--> cast
# cast --nsubj--> get
# do --aux--> get
# not --neg--> get
# get --ccomp--> say
# much --amod--> impact
# impact --compound--> way
# way --npadvmod--> get
# fulli --nsubj--> commit
# commit --relcl--> way
# small --amod--> part
# part --dobj--> commit
# austin --nmod--> butler
# butler --nmod--> film
# major --amod--> film
# highlight --compound--> film
# film --compound--> honestli
# describ --compound--> honestli
# psychot --compound--> honestli
# honestli --dobj--> commit
# that --nsubj--> put
# put --relcl--> honestli
# mildli --compound--> imperson
# deliber --compound--> imperson
# imperson --compound--> work
# baron --compound--> realli
# realli --compound--> work
# work --dobj--> put
# make --aux--> unsettlingit
# even --advmod--> unsettlingit
# unsettlingit --conj--> get
# clear --amod--> bath
# first --amod--> action
# major --amod--> action
# action --compound--> sequenc
# sequenc --compound--> bath
# bath --compound--> director
# beauti --compound--> orang
# orang --compound--> director
# hue --compound--> director
# director --compound--> point
# deni --compound--> villeneuv
# villeneuv --compound--> point
# master --compound--> craft
# craft --compound--> point
# point --dobj--> unsettlingit
# even --advmod--> compar
# compar --compound--> part
# part --appos--> point
# one --nummod--> scale
# scale --compound--> immen
# chapter --compound--> immen
# immen --nsubj--> return
# return --ROOT--> return
# cinematograph --compound--> fraser
# greig --compound--> fraser
# fraser --dobj--> return
# bring --advcl--> return
# specif --npadvmod--> set
# set --amod--> skill
# skill --dobj--> bring
# make --dep--> return
# undeni --amod--> cinemat
# cinemat --nsubj--> eventconsid
# eventconsid --ccomp--> make
# good --amod--> score
# previou --compound--> score
# score --compound--> couldv
# han --compound--> couldv
# zimmer --compound--> couldv
# couldv --compound--> coast
# easili --compound--> coast
# coast --compound--> obviou
# one --nummod--> obviou
# reus --compound--> obviou
# theme --compound--> obviou
# obviou --nsubj--> clearli
# would --aux--> clearli
# not --neg--> clearli
# clearli --ccomp--> eventconsid
# love --dobj--> clearli
# play --compound--> sandbox
# sandbox --nmod--> piec
# almost --advmod--> everi
# everi --amod--> piec
# transcend --compound--> piec
# piec --ccomp--> clearli
# last --amod--> time
# time --npadvmod--> clearli
# still --advmod--> present
# present --ccomp--> clearli
# there --advmod--> present
# new --amod--> one
# one --nummod--> memor
# equal --amod--> memor
# memor --npadvmod--> return
#
# Parsing completed for all sentences.

# %% [markdown]
# # (3) Named Entity Recognition

# %%
import spacy
import pandas as pd
from collections import Counter

# Loading the  spaCy model
nlp = spacy.load("en_core_web_sm")

def perform_ner(text):
    doc = nlp(text)
    return [(ent.text, ent.label_) for ent in doc.ents]

# Loading  the cleaned-data
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Performing the  NER on all the cleaned texts extrcated from csv file
all_entities = []

for index, row in dataFrame.iterrows():
    text = row['Lemmatized']
    entities = perform_ner(text)
    all_entities.extend(entities)

    # Printing all entities for each text
    print(f"\nEntities in text {index + 1}:")
    for entity, label in entities:
        print(f"{entity} - {label}")

# Calculating  the count of each and every entity type
entity_counts = Counter(label for _, label in all_entities)

print("\nTotal entity counts:")
for entity_type, count in entity_counts.items():
    print(f"{entity_type}: {count}")

# Creating  a list of all unique entities
unique_entities = list(set(all_entities))

print("\nSample of unique entities found (up to 20):")
for entity, label in unique_entities[:20]:
    print(f"{entity} - {label}")

# Saving the results to CSV
results_dataFrame = pd.DataFrame(unique_entities, columns=['Entity', 'Type'])
results_dataFrame.to_csv('named_entities.csv', index=False)
print("\nFull list of named entities saved to 'named_entities.csv'")
# Out:
# Streaming output truncated to the last 5000 lines.
# Entities in text 491:
# yesterday - DATE
# embrac messiah destini perfectzendaya - ORG
# javier bardem - PERSON
# first - ORDINAL
# one - CARDINAL
# beautifulth - ORG
#
# Entities in text 492:
# deni - NORP
# surpris - NORP
# han - NORP
# everi time - PERSON
# paul - PERSON
# believ mayb - ORG
# frank herbert - PERSON
# mayb frank - PERSON
#
# Entities in text 493:
# grandeur depth - ORG
# two - CARDINAL
# challeng soar - PERSON
# coloss narr - PERSON
# frank herbert semin - PERSON
# narr expans - PERSON
# first - ORDINAL
# paul - PERSON
# journey naiv young duke - PERSON
# harden realiti - PERSON
# destini desirerebecca - PERSON
# harkonnen depict grotesqu opul repel - ORG
# harkonnen figur - PERSON
# han - NORP
# two - CARDINAL
# mostli - GPE
# materi hindranc - PERSON
# narr - PERSON
# howev - GPE
# quibbl - PERSON
# two - CARDINAL
# ten - CARDINAL
#
# Entities in text 494:
# two - CARDINAL
# first - ORDINAL
# jessica rebecca - PERSON
# quest aveng - PERSON
# paul - PERSON
# lisan al gaib - PERSON
# zendaya fierc - PERSON
# first - ORDINAL
# first - ORDINAL
# paul chani - PERSON
# paul - PERSON
# legendari - ORG
# first - ORDINAL
# two - CARDINAL
# javier bardem austin butler stilgar feydrautha prop - ORG
# javier includ awesom come time subtl - PERSON
# austin - PERSON
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# two - CARDINAL
# han - NORP
# angel beauti greig fraser - PERSON
# third - ORDINAL
#
# Entities in text 495:
# experi - NORP
# nearli hour - TIME
# testosteron estrogen - PERSON
# spectacl behold - ORG
# one - CARDINAL
#
# Entities in text 496:
# fulli - ORG
# strategi - ORG
#
# Entities in text 497:
# undoubtedli beauti movi costum - ORG
# carrier varieti imagin design - PERSON
# first - ORDINAL
# one - CARDINAL
# herbert - PERSON
# issu - ORG
# herbert one - PERSON
# chang alia - PERSON
# chang issu - PERSON
# paul vision - PERSON
# chang metooraci - PERSON
# inevit paul - PERSON
# issu - ORG
# issu - ORG
# herbert provid - PERSON
#
# Entities in text 498:
# two - CARDINAL
# mesmer univer fan - ORG
# first - ORDINAL
# deni villeneuv - PERSON
# frank herbert - PERSON
# everi detail - PERSON
# two - CARDINAL
# captiv beauti - PERSON
# spectacl substanc - ORG
# prais receiv - PERSON
# two - CARDINAL
#
# Entities in text 499:
# friend warn - ORG
# paul - PERSON
# shot movi zendaya constip - ORG
# paul chase - PERSON
#
# Entities in text 500:
# zendaya liter bad - PERSON
# movi movi mani - ORG
#
# Entities in text 501:
# first - ORDINAL
# two - CARDINAL
# frank herbert vision - PERSON
# carri beauti - PERSON
# half hour - TIME
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
# one - CARDINAL
# two - CARDINAL
# greek - NORP
# austin butler perform one - PERSON
# feyd psychot - PERSON
# journey transcend experi quickli - PERSON
# paul atreidu - PERSON
# paul make - PERSON
# three - CARDINAL
# han - NORP
#
# Entities in text 502:
# someth - ORDINAL
# levelif - PERSON
# lover movi - ORG
#
# Entities in text 503:
# polish - NORP
# everi charact great accuraci truli - PERSON
#
# Entities in text 504:
# manag magic - PERSON
# beauti sceneri - PERSON
# jessica - PERSON
# one - CARDINAL
# ten - CARDINAL
# tri kill - PERSON
# surviv - GPE
# truli lamei - PERSON
# eight - CARDINAL
# creativ movi deliv - ORG
# year - DATE
#
# Entities in text 505:
# two - CARDINAL
#
# Entities in text 506:
# two - CARDINAL
# spectacl - ORG
# undeni - NORP
# frank herbert - PERSON
# first - ORDINAL
# half - CARDINAL
# two - CARDINAL
# significantli - ORG
# one - CARDINAL
# two - CARDINAL
# artistri flairth movi pick - ORG
# first - ORDINAL
# jessica - PERSON
# paul jessica - PERSON
# first hour - TIME
# harkonnen militari - PERSON
# liter emerg - PERSON
# operat - ORG
# chao dave bautista cannili sketch - PERSON
# rabban harkonnen - PERSON
# harkonnen control - PERSON
# two - CARDINAL
# paul - PERSON
# nervou young - PERSON
# first - ORDINAL
# javier bardem - PERSON
# paul atreid - PERSON
# paul savior - PERSON
# zendaya paul - PERSON
# two - CARDINAL
# visionari - ORG
# deni villeneuv - PERSON
# narr experi intellectu - PERSON
# two - CARDINAL
# forg - ORG
#
# Entities in text 507:
# armi destroy - ORG
# armi - ORG
# battl - PERSON
# relat - PERSON
# one - CARDINAL
# two - CARDINAL
# el shortli walk realis charact care littl - ORG
# second - ORDINAL
#
# Entities in text 508:
# first - ORDINAL
# two - CARDINAL
#
# Entities in text 509:
# one - CARDINAL
# disappointedi big fan book - ORG
# first - ORDINAL
# two - CARDINAL
# everi second - PERSON
# paul - PERSON
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 510:
# two - CARDINAL
# significantli - ORG
# narr depth - ORG
# first - ORDINAL
# univer frank herbert icon - ORG
# seri - NORP
# superfici spectacleth film pace - PERSON
# issu oscil - ORG
# narr - PERSON
# introduc - PERSON
# selv - PERSON
# two - CARDINAL
# sourc materi den polit intrigu - PERSON
# replac - ORG
# first - ORDINAL
# two - CARDINAL
# superfici diehard fan - ORG
# first - ORDINAL
#
# Entities in text 511:
# jessica jessica - PERSON
# nervou timechani nah someth wrong zendaya - PERSON
# jessica look extrem - PERSON
# mevisu - GPE
# anya taylorjoy jason - PERSON
#
# Entities in text 512:
# magnific - ORG
# one - CARDINAL
# correctli - PERSON
#
# Entities in text 513:
# describ movi one - ORG
# perfectiondeni - ORG
# ingeni - NORP
# breathtak sceneri movi - PERSON
# han - NORP
#
# Entities in text 514:
# everi movi - PERSON
# last week - DATE
# first - ORDINAL
# today - DATE
# everi singl - PERSON
# almost hour - TIME
# everi - ORG
# honestli carri movi - PERSON
# seri - NORP
# austin butler - PERSON
# everi actor - PERSON
#
# Entities in text 515:
# reader book lover - PERSON
# paul atreid - ORG
# reveng - PERSON
# challeng - PERSON
# han - NORP
# sci - ORG
# lover cinemat experi - ORG
#
# Entities in text 516:
# two - CARDINAL
# first - ORDINAL
# deni villeneuv - PERSON
# first - ORDINAL
# frank herbert novel - PERSON
# paul atreid - PERSON
# everi detail - PERSON
# han - NORP
# experiencedun - GPE
# two - CARDINAL
# spectacl substanc - ORG
# genr testament - PRODUCT
#
# Entities in text 517:
# paul - PERSON
# seven - CARDINAL
#
# Entities in text 518:
# absolut amazingth - PERSON
# paul - PERSON
# reveng - PERSON
# one - CARDINAL
# nextth - GPE
# motiv paul timeth - PERSON
# mark memor - PERSON
#
# Entities in text 519:
# first - ORDINAL
# three - CARDINAL
# reveng - PERSON
#
# Entities in text 520:
# second - ORDINAL
# lynch movi - ORG
# lynch chang - PERSON
# paul sister - PERSON
# lynch movi tv - ORG
# paul - PERSON
# jeopardi face atreid - PERSON
# p end p novel lynch movi problem - ORG
# year - DATE
# lynch movi - ORG
# year ago - DATE
# p p - ORG
# materi - DATE
# skinni - NORP
# p start p - ORG
# kyle maclachlan - PERSON
# paul muaddib atreid - PERSON
# crusad - PERSON
# paul chani - PERSON
# first - ORDINAL
# againno thufir hawat - PERSON
# fenr guild - ORG
# harah reason - PERSON
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 521:
# year ago - DATE
# david lynch - PERSON
# rip offf - PERSON
# timeabosut - GPE
# stilgar arabchiani - PERSON
#
# Entities in text 522:
# first - ORDINAL
# betteri - GPE
# paul - PERSON
# meaty materi - PERSON
# first - ORDINAL
# second - ORDINAL
# han - NORP
#
# Entities in text 523:
# journey direct deni villeneuv - PERSON
# paul atreid destini - ORG
# first - ORDINAL
# arraki narr - PERSON
# frank herbert univer - PERSON
#
# Entities in text 524:
# everyon - CARDINAL
#
# Entities in text 525:
# tri nitpick - PERSON
# gom - CARDINAL
# itand movi - ORG
# first - ORDINAL
#
# Entities in text 526:
# adeptli continu - ORG
# frank herbert - PERSON
# spectacl - ORG
# narr themesmoreov - PERSON
# thrill - GPE
# deni villeneuv - PERSON
# second - ORDINAL
# herbert vision - PERSON
# genr admir - PRODUCT
# visionari filmmak - ORG
#
# Entities in text 527:
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
# vladimir harkonnen - PERSON
# dave bautista - PERSON
# first - ORDINAL
# second - ORDINAL
# paul - PERSON
# jessica rebecca - PERSON
# harkonnen - GPE
# first - ORDINAL
# paul - PERSON
# paul - PERSON
# stilgar javier bardem - PERSON
# paul becom - PERSON
# lisan algaib - PERSON
# peopl duti - PERSON
# battl harkonnen paul - PERSON
# jessica - NORP
# paul young - PERSON
# josh brolin - PERSON
# paul - PERSON
# jessica - PERSON
# vladimir harkonnen - PERSON
# requesta psychot - PERSON
# butler join - ORG
# three - CARDINAL
# harkonnen emperor - ORG
# paul - PERSON
# everi singl - PERSON
# paul - PERSON
# paul gurney help roll dice - PERSON
# harkonnen cheer paul - PERSON
# hungri reveng - PERSON
# feydrautha paul - PERSON
# paul - PERSON
# mostli aveng - PERSON
# paul ultim - ORG
# paul - PERSON
# paul - PERSON
# three - CARDINAL
#
# Entities in text 528:
# sci - ORG
# notionth - ORDINAL
#
# Entities in text 529:
# one - CARDINAL
# creativ breathtak visual - PERSON
# midway point someth - FAC
# daeneri - NORP
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 530:
# deni villeneuv - PERSON
# frank herbert - PERSON
# intric plotlin charact arcsth cinematographi visual feast - PERSON
# han - NORP
# experi perfectli - ORG
# narrativedun part - PERSON
# converg deliv truli - ORG
#
# Entities in text 531:
# believ paul meteor - PERSON
# month - DATE
# mayb - GPE
# year - DATE
# experi - NORP
#
# Entities in text 532:
# first - ORDINAL
# hakonnen bald - PERSON
# first hour - TIME
# first - ORDINAL
#
# Entities in text 533:
# imax afternoon - PERSON
# first - ORDINAL
# one - CARDINAL
# believ - GPE
# paul godli - PERSON
# one - CARDINAL
# chang - PERSON
# one - CARDINAL
# chang - PERSON
# three - CARDINAL
#
# Entities in text 534:
# filmim massiv fan - ORG
# first - ORDINAL
# austin butler - PERSON
# mesmeris - NORP
#
# Entities in text 535:
# journey paul atreid visual stun - PERSON
# subtli - DATE
# necessari detail - ORG
# deni villeneuv - PERSON
# second - ORDINAL
#
# Entities in text 536:
# everi - PRODUCT
# everi detail - PERSON
#
# Entities in text 537:
# one - CARDINAL
# first - ORDINAL
# surpris - NORP
# cooki - ORG
#
# Entities in text 538:
# two - CARDINAL
# frank herbert direct deni villeneuv film - PERSON
# paul atreid - PERSON
# narr - PERSON
# two - CARDINAL
# two - CARDINAL
# paul atreid - PERSON
# sourc valuabl spice melang - PERSON
# inten polit - PERSON
# paul - PERSON
# harkonnen lead downfal paul journey desert discov destini prophesi messiah figur kwisatz - PERSON
# paul - PERSON
# jessica rebecca - PERSON
# ferguson - ORG
# forc nativ - PERSON
# two - CARDINAL
# first - ORDINAL
# paul - PERSON
# harkonnen imperi alli - PERSON
# paul embrac - PERSON
# two - CARDINAL
# free paul - PERSON
# believ - GPE
# two - CARDINAL
# han - NORP
# two - CARDINAL
# paul - PERSON
# atreid paul - PERSON
# javier bardem stilgar - PERSON
# two - CARDINAL
# first - ORDINAL
# narr stun - PERSON
# one - CARDINAL
# today - DATE
#
# Entities in text 539:
# year - DATE
# dri everyth - PERSON
# issu - ORG
#
# Entities in text 540:
# rang believ - PERSON
# everi singl - PERSON
# one - CARDINAL
#
# Entities in text 541:
# one - CARDINAL
#
# Entities in text 542:
# guid - WORK_OF_ART
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 543:
# fir place - PERSON
#
# Entities in text 544:
# one - CARDINAL
# first - ORDINAL
# second - ORDINAL
# three - CARDINAL
# everi impresiion movi - ORG
# realli genr - PERSON
# three - CARDINAL
#
# Entities in text 545:
# one - CARDINAL
# everi - ORG
# skill precis - PERSON
# movi pandem gener - ORG
# oasi desert great job - PERSON
#
# Entities in text 546:
#
# Entities in text 547:
# one - CARDINAL
# third - ORDINAL
#
# Entities in text 548:
# one - CARDINAL
# first - ORDINAL
# two - CARDINAL
#
# Entities in text 549:
# funni - ORG
# mommi issu - PERSON
# scifi fantazi - PERSON
# everi scene - PRODUCT
# han zimmer - LOC
# genr scifi - PRODUCT
# paul sudden - PERSON
# chang - PERSON
# third - ORDINAL
# austin butler - PERSON
# austin butler role elvisth - PERSON
# paul - PERSON
# scene paul - PERSON
#
# Entities in text 550:
# anna taylorjoy - PERSON
# experi - NORP
# narr - PERSON
# issu - ORG
#
# Entities in text 551:
# javi bardem charact - PERSON
# style substanc - ORG
#
# Entities in text 552:
# deni villeneuv manag - PERSON
# two - CARDINAL
# one - CARDINAL
# organicallydeni - GPE
#
# Entities in text 553:
# deni villeneuv film struggl - PERSON
# narr - PERSON
# issu - ORG
# third - ORDINAL
# third - ORDINAL
# past first hour - TIME
# one - CARDINAL
# acknowledg unfortun sen - PERSON
# one - CARDINAL
# appar accord - PERSON
# exactli - ORG
# paul - PERSON
# nth - ORDINAL
# two - CARDINAL
# appar suppos carri narr - PERSON
# two - CARDINAL
# second - ORDINAL
# austin butler feydrautha charact - PERSON
# dave bautista beast - PERSON
# first - ORDINAL
# paul chani - PERSON
# arraki howev moment visual brillianc sometim - PERSON
# gravita - PERSON
# narr - ORG
# unfortun - PERSON
# confu look old - PERSON
# narr - PERSON
#
# Entities in text 554:
# battl bstard show - PERSON
# paul chani - PERSON
# paul freman - PERSON
# thrill - GPE
# paul feyd mani - PERSON
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
#
# Entities in text 555:
# two - CARDINAL
# seri - NORP
# seri - NORP
# believ - GPE
# seri - NORP
# moviego - GPE
# believ deni - PERSON
# one - CARDINAL
# one - CARDINAL
# two - CARDINAL
# chang storylin - PERSON
# linear - ORG
# deni jon - PERSON
# storylin fierc crueldun - PERSON
# two - CARDINAL
# perfectionim blow - PERSON
# deni manag - NORP
# two - CARDINAL
# getsth - PERSON
# one - CARDINAL
# eyecatch experi - PERSON
# chang film captur - PERSON
# deni villeneuv - PERSON
# one - CARDINAL
# two - CARDINAL
# everi emot - PERSON
# two - CARDINAL
# rang actingaustin butler feydrautha - PERSON
# austin - PERSON
# everi - PERSON
# languagedavid peterson deni manag - PERSON
# two - CARDINAL
# experi - NORP
#
# Entities in text 556:
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# expectationsdeni - ORG
# sourc materi long - PERSON
# one - CARDINAL
#
# Entities in text 557:
# everi time - PERSON
# everi moment - NORP
# cri - NORP
# freeman - PERSON
# villeneuv everyth - PERSON
# beauti favorit actor butler - ORG
# coloss maestro height - PERSON
#
# Entities in text 558:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# oppenheim - GPE
# third - ORDINAL
#
# Entities in text 559:
# one - CARDINAL
# gener - PERSON
# everyth - ORG
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 560:
#
# Entities in text 561:
# first - ORDINAL
# armi - ORG
# worshipp paul - PERSON
# believ himw - ORG
# first - ORDINAL
# paul - PERSON
# replac - ORG
# spectacl - ORG
#
# Entities in text 562:
# believ messiah - ORG
#
# Entities in text 563:
# two - CARDINAL
# one - CARDINAL
# austin butler - PERSON
# everi perform - PERSON
# mayb spielberg - PERSON
#
# Entities in text 564:
# honestli - PERSON
# night - TIME
#
# Entities in text 565:
# paul destin - PERSON
# mani peopl - PERSON
#
# Entities in text 566:
# everi shoot - PERSON
# everi time - PERSON
#
# Entities in text 567:
# shot ton tini detail - PERSON
# paul send - PERSON
# nitpicki - NORP
#
# Entities in text 568:
# two - CARDINAL
# first - ORDINAL
# recent year - DATE
# photographi greig - PERSON
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 569:
# everi detail - PERSON
# han - NORP
#
# Entities in text 570:
# one - CARDINAL
# sci fi movi - ORG
# paul atriedi - PERSON
# one - CARDINAL
# narr movi pace - ORG
# chang realli good becom - PERSON
#
# Entities in text 571:
# seri - NORP
# one - CARDINAL
# hour - TIME
# third - ORDINAL
#
# Entities in text 572:
# someth - ORDINAL
# han - NORP
# one - CARDINAL
#
# Entities in text 573:
# first - ORDINAL
# two - CARDINAL
# two - CARDINAL
# one - CARDINAL
# deni villeneuv - PERSON
# gorgeou - NORP
# two - CARDINAL
# frank herbert vision - PERSON
# one - CARDINAL
# ofth - ORDINAL
# one - CARDINAL
# besid rebecca - GPE
# ferguson javier bardem - ORG
# gravita - PERSON
# first - ORDINAL
# six month - DATE
# chang bother save - PERSON
# spectacl - ORG
#
# Entities in text 574:
# awar - PERSON
# first - ORDINAL
# one - CARDINAL
# one hour - TIME
# fifteen - CARDINAL
# sci fi experi - ORG
# halfway - ORG
#
# Entities in text 575:
# deni villeneuv - PERSON
# villeneuv howev - PERSON
# frank herbert craft - PERSON
# two hour - TIME
# one - CARDINAL
# today - DATE
#
# Entities in text 576:
# fulli - PERSON
# first - ORDINAL
# seri - NORP
# seri - NORP
#
# Entities in text 577:
# captiv stun - PERSON
# meth meticul - PERSON
# attent detail incre - ORG
# deni villeneuv - PERSON
# han - NORP
#
# Entities in text 578:
# first - ORDINAL
# unsur - GPE
# deni villneuv - PERSON
# reveng - PERSON
# today - DATE
#
# Entities in text 579:
# geniu deni - PERSON
# five - CARDINAL
# paul - PERSON
#
# Entities in text 580:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# harkonnen much wor paul - PERSON
# first - ORDINAL
# javier bardem josh brolin - ORG
# dave bautista surpris rang - PERSON
# villeneuv helm - PERSON
# two - CARDINAL
# second - ORDINAL
# half - CARDINAL
# almost hour - TIME
# issu - PERSON
# first - ORDINAL
# one - CARDINAL
# increa sen - PERSON
# interplanetari - NORP
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# realli introduc messiah howev - PERSON
# paul - PERSON
#
# Entities in text 581:
# movi long - ORG
# experi mani - PERSON
#
# Entities in text 582:
# absolut mesmeris start finish - PERSON
#
# Entities in text 583:
# minut sinc - PERSON
# two - CARDINAL
# two - CARDINAL
# austin butler transform - PERSON
# javier bardem steal scene - PERSON
# two - CARDINAL
#
# Entities in text 584:
# first - ORDINAL
#
# Entities in text 585:
# two - CARDINAL
# first - ORDINAL
# second - ORDINAL
# half - CARDINAL
# first - ORDINAL
# deni villeneuv entir - PERSON
# one - CARDINAL
# ten - CARDINAL
# han - NORP
# greatli greig fraser - PERSON
# beauti tango - PERSON
# everi - PERSON
# one - CARDINAL
# deni viellenuev - PERSON
# everi - PERSON
# paul atreid - PERSON
# zendaya chani beauti chemistri - PERSON
# paul atreid irreplic - ORG
# four - CARDINAL
# everi person - PERSON
# first - ORDINAL
# anymor deni villeneuv - PERSON
# sourc materi - PERSON
# frank herbert - PERSON
# second - ORDINAL
# sourc materi - ORG
# insan creativ - PERSON
# first - ORDINAL
# first - ORDINAL
# everi chapter - PERSON
# first - ORDINAL
# first - ORDINAL
# gom - CARDINAL
# one - CARDINAL
# purpos brilliantli - ORG
# one - CARDINAL
# jessica - PERSON
# paul - PERSON
# half - CARDINAL
# worri - PRODUCT
# one - CARDINAL
# realli dark underton - PERSON
# frank herbert - PERSON
# second - ORDINAL
# paul - PERSON
# deni handl - PERSON
# fulli - PERSON
# paul kill - PERSON
# jessica talk alia - PERSON
# cool perfectli - ORG
# bondeveri battl - PERSON
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# atreid harkonnen sardaukar - ORG
# one - CARDINAL
# everi watch - PERSON
#
# Entities in text 586:
# awesom stun - PERSON
# paul - PERSON
# han - NORP
# freeman harkon - PERSON
# narr movi - ORG
#
# Entities in text 587:
# first - ORDINAL
# timeeveryth movi - ORG
# experi - NORP
#
# Entities in text 588:
# one - CARDINAL
#
# Entities in text 589:
# first - ORDINAL
# two - CARDINAL
# everyth movi - ORG
# second - ORDINAL
# first - ORDINAL
# materi chang - PERSON
# whine movi exactli - ORG
# deserv - PERSON
#
# Entities in text 590:
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 591:
# second - ORDINAL
# half - CARDINAL
# chang squander - PERSON
# narrat - ORG
# paul - PERSON
# david lynch - PERSON
# duke - ORG
# someth deni - PERSON
# dedic relationship paul - PERSON
# believ time - ORG
# second - ORDINAL
# bene gesser - PERSON
# paul sister - PERSON
# josh brolin - PERSON
# third - ORDINAL
# two - CARDINAL
# paul - PERSON
# david lynch - PERSON
# narr howev - PERSON
# gravita strateg brillianc display - ORG
# austin - PERSON
# butler - ORG
# surpris mei - PERSON
# harkonnen perver natur - PERSON
# partli sinc book - PERSON
# frank herbert time - PERSON
# one - CARDINAL
# polit marriag - PERSON
# day - DATE
# two - CARDINAL
# frank herbert - PERSON
# messiah capitalis - ORG
#
# Entities in text 592:
# hardli describ movi make - ORG
# everi punch - PERSON
# kick stab - PERSON
# feyd rautha - PERSON
# knight costar - ORG
# javier bardem - PERSON
# howev absolut - PERSON
# josh brolin - PERSON
# rebecca ferguson zendaya movi - PERSON
# sandgren la la land - PERSON
# roger deakin - PERSON
# everyth movi cinematographi - ORG
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 593:
# third - ORDINAL
# dune messiah plausibl - PRODUCT
# paul sister one - PERSON
# vladimir harkonen - PERSON
# two - CARDINAL
# paul - PERSON
# paul chani - PERSON
#
# Entities in text 594:
# earth - LOC
# two - CARDINAL
# today - DATE
# kingdom earth - GPE
# today - DATE
# one - CARDINAL
#
# Entities in text 595:
# first - ORDINAL
# imax deni villeneuv - PERSON
# narr - ORG
# easi - ORG
# someth planet first time year - DATE
# han - NORP
#
# Entities in text 596:
# one - CARDINAL
#
# Entities in text 597:
# christoph nolan describ film deni empir - ORG
# performancesdeni - ORG
# everi film - PERSON
# one - CARDINAL
# two - CARDINAL
# everi frame - PERSON
# performancewhil zendaya - PERSON
# one - CARDINAL
# two - CARDINAL
# josh brolin - PERSON
# deliv brilliantli austin - ORG
# two - CARDINAL
# han - NORP
# one - CARDINAL
#
# Entities in text 598:
# scifi movi everyth - ORG
# perfectli movi - ORG
# three year - DATE
# everi month - PERSON
# year ago - DATE
# luxuri tasteth - PERSON
# hour - TIME
# two - CARDINAL
#
# Entities in text 599:
# three - CARDINAL
# experi - NORP
#
# Entities in text 600:
# last night - TIME
# frank herbert - PERSON
# brim - ORG
# deni - NORP
# han - NORP
# gorgeou - NORP
# everi shot - PERSON
#
# Entities in text 601:
# polish - NORP
# experi - NORP
# hour movi movi - ORG
# extrem - PERSON
# zero - CARDINAL
# substanc movi - ORG
# first - ORDINAL
#
# Entities in text 602:
# almost hour - TIME
# one - CARDINAL
#
# Entities in text 603:
# loudli unfortun - PERSON
#
# Entities in text 604:
# first - ORDINAL
# two - CARDINAL
# seri - NORP
# david lynch - PERSON
# substanti chang - PERSON
# alia lynch movi - ORG
# dusk night - TIME
# half - CARDINAL
# first - ORDINAL
# distanc appar - PERSON
# mayb realli - PERSON
# first - ORDINAL
#
# Entities in text 605:
# tonight - TIME
# friday - DATE
# mar son - PERSON
# tomorrow - DATE
#
# Entities in text 606:
# everyth absolut - PERSON
# one - CARDINAL
# one - CARDINAL
# han - NORP
# someon el - PERSON
# everi minut movi - PERSON
#
# Entities in text 607:
# gener - PERSON
# screenth - ORDINAL
#
# Entities in text 608:
# deni villeneuv - PERSON
# narr - PERSON
# reson chapter frank herbert legendari - PERSON
# mesmer - ORG
# vista - ORG
# chemistri rebecca ferguson - PERSON
# jessica - PERSON
# motherson relationshipnewcom - PERSON
# includ zendaya mysteri - PERSON
# javier bardem charismat - PERSON
# spectacl - ORG
# depth invit - ORG
# natur - TIME
# narr - PERSON
# second - ORDINAL
# deni villeneuv - PERSON
# nobl - ORG
# detail worldbuild - PERSON
# arraki everi - PERSON
# herbert univer - PERSON
# narr forwardth - ORG
# otherworldli beauti arraki - PERSON
# everi frame - PERSON
# messian figur - ORG
# idaho - GPE
# everi - PRODUCT
# experi - NORP
# challeng us confront - ORG
#
# Entities in text 609:
# beauti part - PERSON
# paul fulfil destini becom - PERSON
# compar boy - PERSON
#
# Entities in text 610:
# realli - PERSON
# chang - PERSON
# today - DATE
# today - DATE
#
# Entities in text 611:
# wham bang - ORG
# everyth - PERSON
#
# Entities in text 612:
# two - CARDINAL
# last year - DATE
# one - CARDINAL
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 613:
# one - CARDINAL
# two - CARDINAL
# seri - NORP
# chang - PERSON
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 614:
# two - CARDINAL
# one - CARDINAL
# javier bardem perform one - PERSON
# hour - TIME
#
# Entities in text 615:
# two - CARDINAL
# two - CARDINAL
# qualiti - ORG
# next year - DATE
# one - CARDINAL
# coupl - PERSON
# frank herbert - PERSON
#
# Entities in text 616:
# frank herbert - PERSON
# necessari watch - ORG
# howev read book part movi like right bookth - WORK_OF_ART
#
# Entities in text 617:
# first - ORDINAL
# two hour - TIME
#
# Entities in text 618:
# seri - NORP
# narr grandeur - ORG
# newcom deni villeneuv directori - PERSON
# han - NORP
# narr - PERSON
# new figur - ORG
# challeng prevail bias - ORG
# fulli - PERSON
#
# Entities in text 619:
# past year - DATE
# mayb one - PERSON
# everi moment - PERSON
# someth - DATE
#
# Entities in text 620:
# movi particularli gorgeou excit - ORG
#
# Entities in text 621:
# zero - CARDINAL
# paul - PERSON
# zero - CARDINAL
# half - CARDINAL
# hour - TIME
#
# Entities in text 622:
# chang book - PERSON
# subtli - EVENT
# significantli - ORG
# jessica chani - PERSON
# materi easi - WORK_OF_ART
#
# Entities in text 623:
# deni villeneuv - PERSON
# frank herbert - PERSON
# expans - NORP
# fulli - GPE
# dunehan - PERSON
# significantli - ORG
# believ rebecca - PERSON
# jessica zendaya - PERSON
# harkonnen javier bardem stilgar bring - PERSON
# notabl critiqu film occasion - ORG
# narr - ORG
# han - NORP
# first - ORDINAL
#
# Entities in text 624:
# prais prais - PERSON
# david lynch - PERSON
# deni villeneuv - PERSON
# first - ORDINAL
# paul atreid - ORG
# sci - ORG
# today - DATE
# today - DATE
# third - ORDINAL
#
# Entities in text 625:
# one - CARDINAL
#
# Entities in text 626:
# two - CARDINAL
# one - CARDINAL
# galvan hairrais - PERSON
# spinetingl soulstir word - PERSON
# outdo captiv - PERSON
# paul atreid - PERSON
# one - CARDINAL
# gener - PERSON
# austin butler - PERSON
# ferguson zendaya josh - ORG
# brolin javier - PERSON
# experi masterpiec movi - ORG
# second - ORDINAL
# third - ORDINAL
#
# Entities in text 627:
# two - CARDINAL
# one - CARDINAL
# everi film - PERSON
# first - ORDINAL
# half - CARDINAL
#
# Entities in text 628:
# deni villeneuv massiv movi - PERSON
# yeari awar - PERSON
# mani movi - ORG
#
# Entities in text 629:
# two - CARDINAL
# two - CARDINAL
# experi leav - PRODUCT
# first - ORDINAL
# herbert legendari saga - PERSON
# paul atreid - PERSON
# paul inner - PERSON
# zendaya chani emerg - PERSON
# paul - PERSON
# rebecca ferguson - PERSON
# jessica mother - PERSON
# bene - PERSON
# javier bardem - PERSON
# meticul - CARDINAL
# woven narr - PERSON
# two - CARDINAL
# paul struggl - PERSON
# two - CARDINAL
# spectacl - ORG
# paul journey - PERSON
# influenceth - DATE
# han - NORP
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
#
# Entities in text 630:
# seri - NORP
# narr mayb - PERSON
# disjoint narr - PERSON
#
# Entities in text 631:
# one - CARDINAL
#
# Entities in text 632:
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# pum - PERSON
# easi easi tasteit - ORG
#
# Entities in text 633:
# one - CARDINAL
# today - DATE
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# aris - GPE
# one - CARDINAL
# nowi - PERSON
# today - DATE
# mesian figur - PERSON
# frank herbert book ala - PERSON
# herbert - PERSON
# first - ORDINAL
# figur disgrac - PERSON
# one - CARDINAL
# paul atreid train - PERSON
# everi - PERSON
# one - CARDINAL
# butlerian jihad - ORG
# basi empir control galaxi - ORG
# ga - ORG
# paul - PERSON
# capac bridg - ORG
# sci fi marvel - ORG
# one - CARDINAL
# one - CARDINAL
# paul unbreak paul - PERSON
# arrakean - NORP
# everi step paul - PERSON
# marriag paul irulan - PERSON
# paul vision exactli - PERSON
# arraki believ - PERSON
# lover believ - PERSON
# one - CARDINAL
# paul - PERSON
# concubin describ - PERSON
# alia atreid one - FAC
# vladimir harkonnen - PERSON
# helen mohiam - PERSON
# year old - DATE
# paul - PERSON
# paul irrit - PERSON
# skinni - ORG
# feydrautha harkonnen - PERSON
# paul - PERSON
# first - ORDINAL
# paul els saidi - PERSON
# one - CARDINAL
# believ - GPE
# mostli nonbeliev - PERSON
# paul - PERSON
# three half year - DATE
#
# Entities in text 634:
# first - ORDINAL
# thrill - GPE
# ten - CARDINAL
# paul - PERSON
# austin butler feydrautha - PERSON
# extrem - PERSON
#
# Entities in text 635:
# paul sister - PERSON
# vladimir harkonnen wherea movi - PERSON
# paul - PERSON
# paul - PERSON
# wasi - PERSON
# togetherveri - NORP
#
# Entities in text 636:
# han - NORP
# movi slightli - PERSON
#
# Entities in text 637:
# one - CARDINAL
# two - CARDINAL
# frank herbert - PERSON
# deni villeneuv - PERSON
# visionari homag - ORG
# two - CARDINAL
# worldbuild extraordinari - PERSON
# audiovisu experi - ORG
# muslim - NORP
# today - DATE
# extraordinari - PERSON
# arriv sicario - ORG
# one - CARDINAL
# two - CARDINAL
# everi - PERSON
# mm - PERSON
# next week - DATE
#
# Entities in text 638:
# second - ORDINAL
# half - CARDINAL
# dunein mani way movi - PERSON
# lisan algaib - PERSON
# believ charact arc book javier bardem show - ORG
# paul rule - PERSON
# trigger devast holi - EVENT
# chang - PERSON
# paul emperor - PERSON
# one - CARDINAL
#
# Entities in text 639:
# two - CARDINAL
# first - ORDINAL
# paul atreid - ORG
# web love duti destini zendaya - ORG
# authenticityth entir cast - ORG
# rebecca ferguson - PERSON
# javier bardem josh - ORG
#
# Entities in text 640:
# seri terrif - PERSON
#
# Entities in text 641:
# chang - PERSON
# flawlessi - ORG
#
# Entities in text 642:
# zero - CARDINAL
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
# gener - PERSON
#
# Entities in text 643:
# paul - PERSON
# reveng - PERSON
# everi moment paint - WORK_OF_ART
# normi - GPE
# one - CARDINAL
# third - ORDINAL
# first - ORDINAL
# overhyp littlebarebon - PERSON
#
# Entities in text 644:
# basi mouth - PERSON
# opendenni villeneuv - PERSON
# han zimmer - PERSON
#
# Entities in text 645:
# hail denni - ORG
# first - ORDINAL
# first - ORDINAL
# half - CARDINAL
# second - ORDINAL
# han zimmer - PERSON
# second - ORDINAL
# half - CARDINAL
# third - ORDINAL
# tragedi - PERSON
# zendaya tim austin - PERSON
#
# Entities in text 646:
# fenr - ORG
# one - CARDINAL
# paul - PERSON
# paul - PERSON
# chang - PERSON
# two - CARDINAL
# naiveti brainwash - PERSON
#
# Entities in text 647:
#
# Entities in text 648:
# colossu - GPE
# mark mileston - PERSON
# frank herbert origin materi - PERSON
# narr - PERSON
# narr choo - ORG
# first - ORDINAL
# brightli actor - ORG
# one - CARDINAL
# everi moment - PERSON
# theme herbert - PERSON
# narr invit - ORG
# herbert vision - PERSON
# narr - ORG
#
# Entities in text 649:
# first - ORDINAL
# deni deliv mani other fail - PERSON
# plu - ORG
# anoth year - DATE
#
# Entities in text 650:
# two - CARDINAL
# thousand - CARDINAL
# two - CARDINAL
# itselfa superb job - PERSON
# two - CARDINAL
# frank herbert novel - PERSON
# deni villeneuv - PERSON
#
# Entities in text 651:
# zendaya rest - PERSON
# first - ORDINAL
# coolnessa big - ORG
#
# Entities in text 652:
# harkonen timelin - PERSON
# year year - DATE
# harkonen attack - PERSON
# first - ORDINAL
# less year - DATE
# dessert kn book - PERSON
# paul - PERSON
#
# Entities in text 653:
# mad messiah movi knife - ORG
# ben geserrit - PERSON
# anya taylor - PERSON
# everi sci - PERSON
# last year - DATE
# fx - ORG
# paul becom messiah - PERSON
#
# Entities in text 654:
# first - ORDINAL
# yesterday - DATE
# one - CARDINAL
# replac - ORG
#
# Entities in text 655:
# first - ORDINAL
# one - CARDINAL
# paul muadib - PERSON
#
# Entities in text 656:
# deni villeneuv - PERSON
# frank herbert dune date - PERSON
# genr - ORG
# five half hour - TIME
# two - CARDINAL
# first - ORDINAL
# javier bardem enrich ensembl castth - PERSON
# austin butler baron - PERSON
# baldpat - PERSON
# two - CARDINAL
# two - CARDINAL
# vison - PERSON
# deni villeneuv - PERSON
#
# Entities in text 657:
# one - CARDINAL
# mayb - GPE
# han - NORP
# everi scene - PERSON
# dreami - GPE
# javier bardem - PERSON
# cri - NORP
# austin kill zendaya kill everi actor - PERSON
# one - CARDINAL
#
# Entities in text 658:
# everi minuteimag - PERSON
# warrantedth - PERSON
#
# Entities in text 659:
# first hour - TIME
# one - CARDINAL
# paul - PERSON
# legendari - ORG
# second - ORDINAL
# fulli - GPE
#
# Entities in text 660:
# deni - NORP
# visionari direct - ORG
# han zimmer mesmer score - ORG
# narr - PERSON
# everi detail - PERSON
# expans - NORP
# paul atreid - PERSON
# paul - PERSON
# jessica oscar - PERSON
# zendaya jason - PERSON
# javier bardem - PERSON
#
# Entities in text 661:
# alia bee bear - PERSON
# paul - PERSON
# two - CARDINAL
# first - ORDINAL
#
# Entities in text 662:
# first - ORDINAL
# second - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# fulli - PERSON
#
# Entities in text 663:
# villeneuv favorit currentwork - PERSON
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# year ago - DATE
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# lackingmani peopl - PRODUCT
# compar movi - ORG
# reinforc miracl lotr - PERSON
# peter jackson - PERSON
# relat - PERSON
# paul atreidesattack - PERSON
# paul chang - PERSON
# chang paul mostli - PERSON
# titan - GPE
# two movi hour - TIME
# appar realli difficult book - PERSON
# adapt visual medium miracl - FAC
# two - CARDINAL
# first - ORDINAL
# realli easi - PERSON
# first - ORDINAL
# unpleasantli - GPE
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 664:
# kick slap - PERSON
# whalelik - PERSON
#
# Entities in text 665:
# islam - NORP
# verg horror - PERSON
# demon dark - PERSON
# second - ORDINAL
#
# Entities in text 666:
# denni villeneuv filmmak - PERSON
# two - CARDINAL
# butler zendayathi truli - ORG
# denni villeneuv enter - PERSON
#
# Entities in text 667:
# someth describ - ORG
# appli beauti detail - PERSON
# first - ORDINAL
# two - CARDINAL
# paul awar gurney halleck gate - PERSON
# javier bardem stilgar absolut - PERSON
# first - ORDINAL
# year - DATE
#
# Entities in text 668:
# deni villeneuv - PERSON
# everi directori - PERSON
# imageri - NORP
#
# Entities in text 669:
# two - CARDINAL
# experi deni villeneuv - PERSON
# spectacl substanc - ORG
# two - CARDINAL
# challeng provok inspir - ORG
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 670:
# chapter dune - LAW
# paul - PERSON
# jessica integr - PERSON
# first - ORDINAL
# perfectli paul atreid - PERSON
# jessica becom - PERSON
# javier bardem zendaya - PERSON
# bardem zendaya great job chani - PERSON
# paul constantli - PERSON
# austin butler - PERSON
# feud ratha - PERSON
# first - ORDINAL
# first - ORDINAL
# han - NORP
# deni - PERSON
# paul journey - PERSON
# one - CARDINAL
#
# Entities in text 671:
# today - DATE
# experi - NORP
#
# Entities in text 672:
# two - CARDINAL
# austin butler - PERSON
# third - ORDINAL
# narr - ORG
# dune messiah potenti child - PRODUCT
# intrigu challeng - PERSON
# deni villeneuv helm - PERSON
#
# Entities in text 673:
# paul - PERSON
# warsremov weaken - PERSON
# versiona littl - PERSON
#
# Entities in text 674:
# year - DATE
# first - ORDINAL
#
# Entities in text 675:
# everi scene - PERSON
# han - NORP
# anyth worth - PERSON
# nd time - PERSON
# third - ORDINAL
#
# Entities in text 676:
# everi anglecaptiv - PERSON
# perfectli - ORG
#
# Entities in text 677:
# austin - PERSON
# han - NORP
# deni villeneuv truli - PERSON
#
# Entities in text 678:
# two - CARDINAL
# first - ORDINAL
# paul - PERSON
# second - ORDINAL
# two - CARDINAL
# first - ORDINAL
# paul second - PERSON
# paul harken - PERSON
# beauti deserv - PERSON
#
# Entities in text 679:
# jurass park - PERSON
# year sinc - DATE
# tonight - TIME
#
# Entities in text 680:
# first - ORDINAL
# philosophi polit - PERSON
# two - CARDINAL
# first - ORDINAL
#
# Entities in text 681:
# first - ORDINAL
# one - CARDINAL
# austin - PERSON
#
# Entities in text 682:
# han - NORP
# two - CARDINAL
# frank herbert - PERSON
# paul zendaya - PERSON
# austin butler - PERSON
# first - ORDINAL
#
# Entities in text 683:
# sorri long long long - PERSON
# second - ORDINAL
#
# Entities in text 684:
# first introduc dad arraki - ORG
# david lynch - PERSON
# seri - NORP
# chang - PERSON
# first - ORDINAL
# half - CARDINAL
# second - ORDINAL
# half - CARDINAL
# first - ORDINAL
# herbert - PERSON
# second - ORDINAL
# first - ORDINAL
# chang wholesal - PERSON
# gom - CARDINAL
# seri - NORP
# one - CARDINAL
# bear surpris present court - ORG
# paul messag - PERSON
# one - CARDINAL
# fulli - PERSON
# spi constantli - PERSON
# everi singl - PERSON
# spice melang - PERSON
# seri - NORP
# coursein - PERSON
# includ paul - PERSON
# nobl - ORG
# linethi crusad - PERSON
# million - CARDINAL
# hour - TIME
# challeng - PERSON
# first - ORDINAL
# sardaukar - PERSON
# paul - PERSON
# first - ORDINAL
# harkonnen result - PERSON
# first - ORDINAL
# paul - PERSON
# first - ORDINAL
# one - CARDINAL
# battleth sardaukar - PERSON
# golden compani - PERSON
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# everi - NORP
# hong kong - GPE
# us militari - PERSON
# hk presid - PERSON
# second - ORDINAL
# half - CARDINAL
#
# Entities in text 685:
# two - CARDINAL
# chang - PERSON
#
# Entities in text 686:
# first - ORDINAL
# first - ORDINAL
# heavi movi brood dark seriou movi - ORG
# paul jessica - PERSON
# diverg - PERSON
# paul integr - PERSON
# year - DATE
# bear memori ancestor - ORG
# summer - DATE
# movi secondli chani - ORG
# diverg howev - PERSON
# villeneuv condens - PERSON
# frank herbert - PERSON
# one - CARDINAL
# american - NORP
# els modifi - PERSON
# austin butler - PERSON
# terrif - PERSON
#
# Entities in text 687:
# undoubtedli one - PERSON
# everi box hard pinpoint - PERSON
# advanc plotth film - ORG
# villneuv worldhowev - PERSON
# harkonnen arena - PERSON
# el develop - ORG
# battl paul - PERSON
# paul forc - PERSON
# issu movi - ORG
#
# Entities in text 688:
# first - ORDINAL
# moviego - GPE
# creativ movi - ORG
# one - CARDINAL
# everyth movi beauti defin - PERSON
# scifi movi movi beauti - ORG
#
# Entities in text 689:
# first - ORDINAL
# dune paul - PERSON
# chang likabl kid - PERSON
# believ - GPE
# third - ORDINAL
# third - ORDINAL
# first - ORDINAL
# two - CARDINAL
#
# Entities in text 690:
# frank herbert write denni villenneuv - PERSON
# timothe rebeca - ORG
# favourit gener - ORG
# han zimmerno - PERSON
# cinema dune fan - PERSON
# denni manag - PERSON
#
# Entities in text 691:
# first - ORDINAL
# one - CARDINAL
# movi denni - ORG
# everi - NORP
#
# Entities in text 692:
# someth magnific - EVENT
# year later - DATE
# two day - DATE
# lisan al gaib - PERSON
# paul feyd - PERSON
# paul harkonnen attack - PERSON
# besid han zimmer - PERSON
# dave timoth - PERSON
# zendaya rebecca - PERSON
# javier josh - PERSON
# theyr - DATE
# one - CARDINAL
# besid act someth - ORG
# feyd paul - PERSON
# legendari - ORG
# two - CARDINAL
# everi mundan - PERSON
# polit chao ineffici - PERSON
# believ detail - ORG
# second - ORDINAL
# seri extrem - PERSON
# motiv - PERSON
# next year - DATE
#
# Entities in text 693:
# frank herbert - PERSON
# year - DATE
# surpris - ORG
# disappointedth - PERSON
# paul chani - PERSON
# wantingperson - ORG
# chaniveri - GPE
# storylin - GPE
#
# Entities in text 694:
# robberi - GPE
# oppenheim - GPE
# japan franc watch - ORG
# disney movi imagin critic - ORG
#
# Entities in text 695:
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# beauti everi scene - PERSON
# narr creat - PERSON
# fulli - PERSON
# worldhowev - GPE
# first - ORDINAL
# narr - ORG
# first - ORDINAL
# wellpac ensur - ORG
# everi moment - PERSON
# first - ORDINAL
# seri - NORP
# jewel modern filmmak - PERSON
#
# Entities in text 696:
# one - CARDINAL
# two - CARDINAL
# third - ORDINAL
# third - ORDINAL
# austin butler scari - PERSON
# paul - PERSON
# one - CARDINAL
# durat movi - ORG
#
# Entities in text 697:
# first - ORDINAL
# us benegesserit show beauti - PERSON
# frank herbert geniu time - PERSON
# everi prais - PERSON
# audienceth first - DATE
# second - ORDINAL
# paul jessica - PERSON
# second - ORDINAL
# prais deni villeneuv geniu - PERSON
# third - ORDINAL
#
# Entities in text 698:
# genr entir planetarriv - ORG
# conquer genr - PERSON
#
# Entities in text 699:
# weekend - DATE
# experi - NORP
# one - CARDINAL
# seri - NORP
# first - ORDINAL
# one - CARDINAL
# brim - ORG
# white harkonnen - ORG
# austin butler realli great - PERSON
# zendaya mani - PERSON
# chang mechan scifi - PERSON
#
# Entities in text 700:
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 701:
# two - CARDINAL
# first - ORDINAL
# deni villeneuv - PERSON
# paul - PERSON
# paul seek reveng - PERSON
# paul - PERSON
# three year later - DATE
# first - ORDINAL
# first - ORDINAL
# deni villeneuv - PERSON
# first - ORDINAL
# second - ORDINAL
# paul chani - PERSON
# second - ORDINAL
# second - ORDINAL
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# second - ORDINAL
# paul chani - PERSON
# deni villeneuv provid beauti visual - PERSON
# photographi - ORG
# greig fraser - PERSON
# first - ORDINAL
# seri - NORP
# two - CARDINAL
# tri aveng harm - PERSON
# first - ORDINAL
# second - ORDINAL
# austin butler - PERSON
# armi - ORG
# josh brolin - PERSON
# unfortun - PERSON
# second - ORDINAL
#
# Entities in text 702:
# everi frame - PERSON
# beauti dune - PERSON
# confus - ORG
#
# Entities in text 703:
# second - ORDINAL
# one - CARDINAL
# first - ORDINAL
# two - CARDINAL
# deni villeneuv tool - PERSON
# believ himand - ORG
#
# Entities in text 704:
# liter gush - PERSON
# chang - PERSON
# one - CARDINAL
# almost hour - TIME
#
# Entities in text 705:
# one - CARDINAL
# han - NORP
# two - CARDINAL
# excellentdeni villeneuv greg - PERSON
# han - NORP
# masteri - PERSON
# everi - PERSON
# zendaya javier bardem rebecca ferguson - PERSON
# brolin dave bautista last - PERSON
#
# Entities in text 706:
# two - CARDINAL
# first - ORDINAL
# paul - PERSON
# bardem love - PERSON
#
# Entities in text 707:
# two - CARDINAL
# second - ORDINAL
# everi singl - PERSON
# one - CARDINAL
# han - NORP
# one - CARDINAL
# two - CARDINAL
# deni villeneuv - PERSON
#
# Entities in text 708:
# simpli stun - PERSON
# everi way gorgeou - PERSON
# brilliantli - ORG
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# astound - NORP
# weekday afternoon - TIME
# everyth make movi - ORG
# nowi believ - PERSON
#
# Entities in text 709:
# two - CARDINAL
# everi breathtak - PERSON
# starkli beauti - PERSON
# spectacl - ORG
# battl frame - PERSON
# two - CARDINAL
# intrigu intensifi - ORG
# spectacl profound - ORG
# first - ORDINAL
#
# Entities in text 710:
# one - CARDINAL
# first - ORDINAL
# everi - ORG
# averag sci - PERSON
# everi scene - PERSON
# techniqu - NORP
# han - NORP
# third - ORDINAL
#
# Entities in text 711:
# one - CARDINAL
# issu movi - ORG
#
# Entities in text 712:
# first - ORDINAL
# first - ORDINAL
# someon manag - PERSON
# thrill - GPE
# root paul - PERSON
# everi second - PERSON
# beautifulultim film choo - PERSON
#
# Entities in text 713:
# first - ORDINAL
# first - ORDINAL
# half - CARDINAL
# first - ORDINAL
# second - ORDINAL
# half - CARDINAL
# first - ORDINAL
# hour - TIME
# first hour - TIME
# paul - PERSON
# believ - GPE
# one - CARDINAL
# paul - PERSON
# armi - ORG
# second - ORDINAL
# mostli - GPE
# first - ORDINAL
# one - CARDINAL
# hour - TIME
# two part hour - TIME
# half - CARDINAL
#
# Entities in text 714:
# first - ORDINAL
# one - CARDINAL
# mostli - GPE
# half - CARDINAL
# two - CARDINAL
# two - CARDINAL
# daeneri - NORP
# throne season - DATE
#
# Entities in text 715:
# two - CARDINAL
# frank herbert - PERSON
# first - ORDINAL
# deni villeneuv - PERSON
# narr - PERSON
# repris - PERSON
# paul atreid deliv nuanc - ORG
# one - CARDINAL
# movi explor mystic - ORG
# first - ORDINAL
# bloodlin prophet - PERSON
# han - NORP
# spectacl - ORG
# chapter breathtak visual compel perform thoughtprovok - LAW
# deni villeneuv place - PERSON
# one - CARDINAL
# visionari - ORG
# today - DATE
#
# Entities in text 716:
# seri - NORP
# today - DATE
#
# Entities in text 717:
# realli miss movi - PERSON
# first - ORDINAL
#
# Entities in text 718:
# two - CARDINAL
# first - ORDINAL
# second - ORDINAL
# everi - PERSON
# deni villeneuv - PERSON
# two - CARDINAL
# first - ORDINAL
# summari star - ORG
# one - CARDINAL
# two - CARDINAL
# quantiti - GPE
#
# Entities in text 719:
# three hour - TIME
# five - CARDINAL
# third - ORDINAL
# third - ORDINAL
#
# Entities in text 720:
# one - CARDINAL
# visionari - ORG
# han - NORP
#
# Entities in text 721:
# movi huge - ORG
# first - ORDINAL
# wor horribl flush - PERSON
# second - ORDINAL
# ondun - GPE
# sourc materi devot - PERSON
# crystal cleardun part culmin hard work dedic commit - ORG
# narr - PERSON
# first - ORDINAL
# paul - PERSON
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# narr - ORG
#
# Entities in text 722:
# ga - ORG
# two - CARDINAL
# first - ORDINAL
# initi - PERSON
# chang lessen - PERSON
# harkonnen - PERSON
# instantli cross - ORG
# first - ORDINAL
# second - ORDINAL
# onth - ORDINAL
# first - ORDINAL
# infin - GPE
# mostli go hill - ORG
# seri - ORG
# seri - NORP
# includ mandalorian - PERSON
# seri - NORP
# mad max - PERSON
# dozen - CARDINAL
#
# Entities in text 723:
# everi scene - PERSON
# chang help onscreen - PERSON
# first - ORDINAL
# paul - PERSON
# explos movi deliv - ORG
# second - ORDINAL
#
# Entities in text 724:
# lipservic herbert - PERSON
#
# Entities in text 725:
# one - CARDINAL
# matur - PERSON
# two - CARDINAL
# purchas mayb - PERSON
# half - CARDINAL
# rebecca ferguson - PERSON
# two - CARDINAL
# half - CARDINAL
# occas glint eye - ORG
# josh brolin javier braden tri - PERSON
# sourc materi - PERSON
# narr - PERSON
# chang sourc materi becom - PERSON
# weak anem - PERSON
# two - CARDINAL
#
# Entities in text 726:
# almost three hour - TIME
# pull herbert book - PERSON
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 727:
# night - TIME
# culmin deni villeneuv - PERSON
# first - ORDINAL
# everi sandworm - PERSON
# everi singl - PERSON
# one - CARDINAL
# qualiti - PERSON
# past year - DATE
#
# Entities in text 728:
# qualiti movi - ORG
# wokisney - ORG
# billion - CARDINAL
# paul - PERSON
#
# Entities in text 729:
# exampl movi - ORG
# first - ORDINAL
# paul - PERSON
# austin butler - PERSON
# feud rautha - PERSON
#
# Entities in text 730:
# dedic projectdun - PERSON
# two - CARDINAL
# linear flow - PERSON
# dose surpriseth - PERSON
# recent year - DATE
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# famou - ORDINAL
# two - CARDINAL
# three - CARDINAL
# paul - PERSON
# frank herbert - PERSON
# second - ORDINAL
# half - CARDINAL
# secondari - NORP
# jessica - PERSON
# vladimir insan job like - PERSON
# first - ORDINAL
# austin butler - PERSON
# film deni - PERSON
# one - CARDINAL
# third - ORDINAL
# year - DATE
# knight star - ORG
# first - ORDINAL
# three - CARDINAL
# makersil - PERSON
# slip sometim - PERSON
# frank herbert - PERSON
#
# Entities in text 731:
# one imagin year - DATE
# entir reveng saga - PERSON
# includ mani - PERSON
# hardli - GPE
# reveng - PERSON
#
# Entities in text 732:
# first - ORDINAL
# beauti hour - PERSON
# paul pre - PERSON
# one - CARDINAL
# year - DATE
# boyjavi bardem fanat stilgar great - ORG
# believ - GPE
# seri everi - PERSON
# brolin - PERSON
# josh brolin - PERSON
# oppenheim - PERSON
# mayb - GPE
# paul - PERSON
# jealousi movi - PERSON
# decentoppenheim - PERSON
#
# Entities in text 733:
# coupl movi - ORG
# nirvana - GPE
# everi way - PERSON
#
# Entities in text 734:
# first - ORDINAL
# jettison - PERSON
# herbert - PERSON
# piec middl - PERSON
# zero - CARDINAL
#
# Entities in text 735:
# one - CARDINAL
# austin elvi butler - PERSON
# almost hour - TIME
# han - NORP
#
# Entities in text 736:
# hahaha movi huge - ORG
# first - ORDINAL
#
# Entities in text 737:
# lisan al gaib - PERSON
# paul - PERSON
# durat movieth entir - ORG
# hour - TIME
# risen challeng - PERSON
#
# Entities in text 738:
# anyon - ORG
# breathtakingli detail - ORG
# frank herbert know - PERSON
# everi film - PERSON
# minimum hour - TIME
# integr herbert - PERSON
# frank herbert son - PERSON
# two - CARDINAL
#
# Entities in text 739:
# spectacl deni - PERSON
# superb exposit - PERSON
# first - ORDINAL
# second - ORDINAL
# han zimmer - PERSON
# jaw drop - PERSON
# paul - PERSON
# harkonnen javier bardem - PERSON
# furi - GPE
# brolin - GPE
# first - ORDINAL
# machineri motion - FAC
# beauti chao battl - PERSON
#
# Entities in text 740:
# masteri craft - PERSON
# immer qualiti - PERSON
# spectacl perform - ORG
#
# Entities in text 741:
# lightli - ORG
# first time year - DATE
# mani triumph experi - PERSON
# inevit - PERSON
# first - ORDINAL
# hour - TIME
#
# Entities in text 742:
# two - CARDINAL
# vista - ORG
# everi frame - PERSON
# two - CARDINAL
# two hour - TIME
# narr - PERSON
# expans - NORP
# two - CARDINAL
# frank herbert belov - PERSON
# third - ORDINAL
#
# Entities in text 743:
# one - CARDINAL
# two - CARDINAL
# two - CARDINAL
# three - CARDINAL
# one - CARDINAL
#
# Entities in text 744:
# experi - NORP
# mm - PERSON
# leicest - GPE
# london - GPE
# first - ORDINAL
# deserv morehav - PERSON
# deni villeneuv - PERSON
# three hour - TIME
# han - NORP
#
# Entities in text 745:
# miniseri - PERSON
# year - DATE
# one - CARDINAL
# chang mani detail - PERSON
# armi - ORG
# last season - DATE
#
# Entities in text 746:
# half - CARDINAL
# everyon - CARDINAL
# one - CARDINAL
# two - CARDINAL
# nobl housesth atreid - ORG
# spice valuabl substanc - PERSON
# necessari interstellar navig - ORG
# paul atreid - PERSON
# believ messiah proof - ORG
#
# Entities in text 747:
# landmark movi - ORG
# shatter vibrat realli - PERSON
# prais deni villeneuv - PERSON
#
# Entities in text 748:
# everi level - PERSON
# showcas harsh beauti arraki world incre - WORK_OF_ART
# zendaya austin - PERSON
# philosoph theme frank herbert novel - PERSON
# two - CARDINAL
# one - CARDINAL
# thrill - ORG
#
# Entities in text 749:
# one - CARDINAL
#
# Entities in text 750:
# experi - NORP
# one - CARDINAL
# two - CARDINAL
# two - CARDINAL
# han - NORP
# depict paul furi ascent - ORG
# han - NORP
# sourc materi scifi - PERSON
# genr - ORG
# experi - NORP
# simultan multifacet - ORG
#
# Entities in text 751:
# today - DATE
# everi occas - PERSON
# two - CARDINAL
#
# Entities in text 752:
# two - CARDINAL
# first - ORDINAL
# deni villeneuv truli - PERSON
# second - ORDINAL
# jawdrop - ORG
# paul atreid - PERSON
# austin butler - PERSON
# one - CARDINAL
# javier bardem - PERSON
# surpris - NORP
# everi scene - PERSON
# everi - PERSON
# first - ORDINAL
# two - CARDINAL
# first - ORDINAL
# everi - PERSON
# two - CARDINAL
#
# Entities in text 753:
# spice valuabl complet - PERSON
# peter jackson magnific - PERSON
#
# Entities in text 754:
#
# Entities in text 755:
# first - ORDINAL
# second - ORDINAL
# everi - PERSON
# second - ORDINAL
# first - ORDINAL
#
# Entities in text 756:
# miniseri world full polit subplot mani charact dv part - WORK_OF_ART
# paul everi - PERSON
# jessica - PRODUCT
# cheni constantli - PRODUCT
# paul becom messiah miniseri - PERSON
# chang book chang - PERSON
# miniseri - PERSON
#
# Entities in text 757:
# first - ORDINAL
# frank hurbert book - PERSON
# second - ORDINAL
# chang whole dynam - ORG
#
# Entities in text 758:
# two - CARDINAL
# year - DATE
# frank herbert masterpiec fool - PERSON
# visionari - PERSON
# everi detail - PERSON
# believ - GPE
# spoton - ORG
# everi battl - PERSON
# thrill - GPE
# two - CARDINAL
# three - CARDINAL
#
# Entities in text 759:
# two - CARDINAL
# one - CARDINAL
# deni villeneuv - PERSON
# two - CARDINAL
# paul atreid - PERSON
# potenti futurestrong - PERSON
# actionheavi - ORDINAL
# two - CARDINAL
# two second half - DATE
# first - ORDINAL
# third - ORDINAL
# two - CARDINAL
# narr - PERSON
# one - CARDINAL
# reson howev viewer - PERSON
# first - ORDINAL
# materi - PERSON
# challeng fulli - PERSON
#
# Entities in text 760:
# beauti - CARDINAL
#
# Entities in text 761:
# inspir - ORG
#
# Entities in text 762:
# absolut blow - PERSON
# art deni villeneuv - PERSON
# everi - PRODUCT
#
# Entities in text 763:
# hour - TIME
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# fulli - PERSON
# effecteveri - NORP
# everi sound - PERSON
# three hour - TIME
# three - CARDINAL
# one magnific - TIME
# one - CARDINAL
# caladan paul chani feyd baron - PERSON
# everi timelong - PERSON
#
# Entities in text 764:
# half - CARDINAL
# dirst - ORDINAL
# half - CARDINAL
# z - DATE
# half - CARDINAL
#
# Entities in text 765:
# everi scene - PERSON
# javier bardem - PERSON
#
# Entities in text 766:
# chang - PERSON
# chang - PERSON
# mona - GPE
#
# Entities in text 767:
# first - ORDINAL
# second - ORDINAL
# seri - NORP
# one - CARDINAL
#
# Entities in text 768:
# one - CARDINAL
# frank herbert loss - PERSON
# mesmeris qualiti desert planet - PERSON
# ...
#
# Entities in text 936:
# first - ORDINAL
# second - ORDINAL
# one - CARDINAL
# million - CARDINAL
# second - ORDINAL
# scene harkonnen - PERSON
# david lynch - PERSON
# harkonnen strang - PERSON
# forc strang - PERSON
# vulner harkonnen troop - ORG
# harkonnen allow - PERSON
#
# Entities in text 937:
# movi - ORG
# chang approach attitud - PERSON
#
# Entities in text 938:
# finalenearli hour - PRODUCT
# someth - CARDINAL
# first - ORDINAL
# first - ORDINAL
# second - ORDINAL
# seri - NORP
#
# Entities in text 939:
# first - ORDINAL
# three - CARDINAL
# second - ORDINAL
# yesterday - DATE
# two - CARDINAL
# mayb - PERSON
# frank herbert name - PERSON
#
# Entities in text 940:
# jessica manipul - PERSON
# paul - PERSON
# everi movi - PERSON
# lisan al gaib - PERSON
# seri - NORP
# feyd brutalist - ORG
# monochrom color - PERSON
# han zimmer - ORG
# battl paul feyd - PERSON
# cultur middl eastern - ORG
# believ - GPE
# realiti movi - ORG
# deni villeneuv - PERSON
#
# Entities in text 941:
# one - CARDINAL
# favourit movi - ORG
# last year - DATE
# second - ORDINAL
# last night - TIME
# masterpieceit long time sinc movi - ORG
# speechlessit deni villeneuv - PERSON
# christoph - ORG
# oppenheim - GPE
# last year - DATE
# peter jackson - PERSON
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
# first - ORDINAL
# jessica ferguson - PERSON
# forese - NORP
# paul - PERSON
# paul - PERSON
# arrakismeanwhil baron - PERSON
# harkonnen continu - PERSON
# butler plate retak planet - ORG
# natur - PERSON
# first - ORDINAL
# legendari - ORG
# han - NORP
# studi lineup absolut - PERSON
# duke - PERSON
# seri - NORP
# harkonnenno countri - PERSON
# josh brolin - PERSON
# javier bardem resum - PERSON
# stilgar offer gravita - PERSON
# christoph - PERSON
# dave batista - PERSON
# one - CARDINAL
# harkonnen skarsgard - PERSON
# second - ORDINAL
# one - CARDINAL
# instalmentth - ORG
# abu dhabiimpact cinemadun - PERSON
# one - CARDINAL
# two - CARDINAL
# staggeringit - GPE
#
# Entities in text 942:
# one - CARDINAL
# han - NORP
# hour - TIME
# believ movi - ORG
#
# Entities in text 943:
# one - CARDINAL
# beauti costumeri - PERSON
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 944:
# one - CARDINAL
# jessica harkonen - PERSON
# battl beauti graphic - PERSON
# paul witch - PERSON
#
# Entities in text 945:
# visionari deni villeneuv noth short - PERSON
# everi frame meticul craft immer viewer - WORK_OF_ART
# frank herbert icon - PERSON
# everi - PRODUCT
# dedic craft grip - PERSON
#
# Entities in text 946:
# everi scene tableau - PERSON
# first - ORDINAL
# first - ORDINAL
# thrill - GPE
#
# Entities in text 947:
# scneri costum - ORG
# one - CARDINAL
# austin butler becom - PERSON
# god - PERSON
# three - CARDINAL
#
# Entities in text 948:
# movieth visual - PERSON
# austin butler - PERSON
# writtenr - GPE
#
# Entities in text 949:
# first - ORDINAL
# gener - PERSON
# third - ORDINAL
#
# Entities in text 950:
# mayb - GPE
# multipl timesth - PERSON
#
# Entities in text 951:
# deni villeneuv - PERSON
# one - CARDINAL
# one - CARDINAL
# paul - PERSON
# two - CARDINAL
# first - ORDINAL
# herbert - PERSON
# three - CARDINAL
# unsurpris sinc - PERSON
# one - CARDINAL
# herbert genr redefin novel - PERSON
# paul sinc - PERSON
# howev - PERSON
# hord sardaukar - PERSON
# muaddibin conclus - PERSON
# deni villeneuv - PERSON
# simultan - NORP
#
# Entities in text 952:
# sourc materi - PERSON
# frank herbert mind emphasi - PERSON
# timmi zendaya - PERSON
# austin butler - PERSON
#
# Entities in text 953:
# four day - DATE
# tragedi beauti - PERSON
# cultiv cultiv degreether - PERSON
# one - CARDINAL
#
# Entities in text 954:
# two - CARDINAL
# frank herbert - PERSON
# deni villeneuv - PERSON
# beauti - CARDINAL
# herbert univer - PERSON
# clariti emot - ORG
# two - CARDINAL
# opul imperi court - PERSON
# realiti - PERSON
# desert intric design - PERSON
# experi truli - PERSON
# two - CARDINAL
# synth - DATE
# battl - PERSON
# herbert univer - PERSON
# spectacl ensnar - ORG
# two - CARDINAL
# interpret paul atreid - PERSON
# challeng herbert intent book - PERSON
# paul - PERSON
# flaw figur - PERSON
# depict paul - PERSON
# paul - PERSON
# narr - PERSON
# herbert critiqu - PERSON
# paul darker - PERSON
# two - CARDINAL
# paul captiv - PERSON
# paul charact - PERSON
# align herbert - PERSON
# paul - PERSON
# cautionari - PERSON
# paul line - PERSON
# herbert intent enrich - PERSON
# narr - ORG
# ambiguitydun part - PERSON
# two - CARDINAL
# majesti herbert univer - PERSON
#
# Entities in text 955:
# one - CARDINAL
#
# Entities in text 956:
# almost hour - TIME
# paul - PERSON
# jessica rebecca - PERSON
# first - ORDINAL
# paul tri - PERSON
# accord prophecydeni villeneuv - PERSON
# frank herbert novel - PERSON
# beauti everi scenedun - PERSON
# paul charact ideal zendaya - ORG
# one - CARDINAL
# jessica - NORP
# villeneuv javier bardem stilgar - PERSON
# austin butler - PERSON
#
# Entities in text 957:
# confus - ORG
#
# Entities in text 958:
# everi scene - PERSON
# everi scene - PERSON
# unfortun - PERSON
# genzal garbag - PERSON
#
# Entities in text 959:
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 960:
# tapestri breathtak - PERSON
# indian - NORP
# frank herbert allianc - PERSON
# everi - PERSON
# everi - NORP
# deni villeneuv - PERSON
# grandeur - ORG
# india - GPE
# narr - ORG
# seri - ORG
# challeng - PERSON
# indian - NORP
# captiv narr - PERSON
# boundari - ORG
# spectacl interstellar warfar cosmic intrigu film explor - ORG
# day - DATE
# spectacl - ORG
# chang experi - PERSON
#
# Entities in text 961:
#
# Entities in text 962:
# first - ORDINAL
# engross mesmeris cinemat marvel - PERSON
# one - CARDINAL
# realiti accompani - ORG
# han zimmer - ORG
# frank herbert - PERSON
#
# Entities in text 963:
# one - CARDINAL
# storylin - GPE
# one - CARDINAL
# skinni - NORP
#
# Entities in text 964:
# pleasur watch movi - ORG
# beauti portray paul journey destini - PERSON
# expertli part - ORG
# one - CARDINAL
# prais greg - PERSON
# everyon - CARDINAL
# everyon - CARDINAL
#
# Entities in text 965:
# downhil second part - PERSON
# fulli - PERSON
# first - ORDINAL
# desert peopl - PERSON
# one - CARDINAL
# first - ORDINAL
# el show drank - ORG
# pregnanc watch movi feel - ORG
# fx - ORG
#
# Entities in text 966:
# one - CARDINAL
# two - CARDINAL
# two - CARDINAL
# fulli - PERSON
# ten moment - TIME
# jessica particularli come - PERSON
# paul - PERSON
# paul - PERSON
#
# Entities in text 967:
# three year - DATE
# first - ORDINAL
# christoph walken - PERSON
# zendaya dave bautista - PERSON
# entir movi harkonnen dummi - ORG
# completli utterli destroy squad harkonnen - ORG
# paul atreid freman - PERSON
# second - ORDINAL
# one - CARDINAL
# paul feydrautha - PERSON
# beauti choreograph - PERSON
# second - ORDINAL
# paul atreid abil - ORG
# first - ORDINAL
# second - ORDINAL
# harkonnen - PERSON
# week end - DATE
#
# Entities in text 968:
# strang pace movi feel - ORG
# first - ORDINAL
# unfortun - PERSON
# journey star - PERSON
# sourc materi book - PERSON
# unfortun - PERSON
# substanc unfortun - PERSON
# confus - ORG
# first - ORDINAL
# two - CARDINAL
# third - ORDINAL
#
# Entities in text 969:
# hour - TIME
# two - CARDINAL
# frank herbert - PERSON
# second - ORDINAL
# spectacl - ORG
# masteri art - PERSON
# paul atreid - PERSON
# know valuabl resourc spice - PERSON
# arraki harkonnen - FAC
# second - ORDINAL
# rebecca ferguson zendaya - PERSON
# austin butler - PERSON
# performancesth - ORG
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 970:
# reader movi adapt - ORG
# everi singl - PERSON
# hour - TIME
# everyon day - DATE
#
# Entities in text 971:
# first - ORDINAL
# second - ORDINAL
# one - CARDINAL
# year - DATE
# year - DATE
# paul harkonen - PERSON
#
# Entities in text 972:
# last week - DATE
# khao lak - PERSON
# day - DATE
# titan - GPE
# four - CARDINAL
# zendaya rebecca - PERSON
# javier bardem mani - PERSON
# everyth movi - ORG
#
# Entities in text 973:
# two - CARDINAL
# second - ORDINAL
# half - CARDINAL
# one - CARDINAL
# imageri - NORP
# two - CARDINAL
# masteri filmmak - PERSON
# everi singl - PERSON
# two - CARDINAL
# next year - DATE
#
# Entities in text 974:
# two - CARDINAL
# one - CARDINAL
# two - CARDINAL
# peter jacksonth - PERSON
# two - CARDINAL
# two - CARDINAL
# sffantasi movi - ORG
# societi mystic - PERSON
# simultan movi superb balanc - ORG
# seri - NORP
# frank herbert publish - PERSON
# chilton publish mainli auto repair - ORG
# societi planet - PERSON
# robert heinlein - PERSON
# inspir - ORG
# italian - NORP
# nobl hous - ORG
# rivalri hous atreid harkonnen form core event paul atreid central charact son duke atreid heir rule - ORG
# harkonnen - PERSON
# harkonnen - PERSON
# mayb - GPE
# atreid loo inspir hous - ORG
# mocenigo venic simpli make hous - ORG
# harkonnen bald albino littl - PERSON
# spice melang - PERSON
# societi arraki - PERSON
# nativ - ORG
# divid sever - PERSON
# interplanetari - PERSON
# societi mystiqu - PERSON
# mostli nonviol - PERSON
# jessica bene - PERSON
# paul motherand - ORG
# melang challeng - PERSON
# two - CARDINAL
# six - CARDINAL
#
# Entities in text 975:
# yesterday - DATE
# austin walkenbardem brolin - PERSON
# half - CARDINAL
# seriosli - DATE
#
# Entities in text 976:
# gorgeou - NORP
# critiqu valid fan know - PERSON
# newbi dunepart - WORK_OF_ART
# seri - NORP
# paul - PERSON
# arc worthwhil - PERSON
#
# Entities in text 977:
# masterpieceit - ORG
# one - CARDINAL
# harkonnen inde exactli harkonnen - ORG
# herbert nice option - PERSON
# javier bardem - PERSON
# first - ORDINAL
# atreid knowit favorit adapt old - ORG
# seri - NORP
# second - ORDINAL
# second - ORDINAL
#
# Entities in text 978:
# deni villeneuv - PERSON
# frank herbert semin novel - PERSON
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
# herbert universevisu breathtak intellectu - PERSON
# everi frame - PERSON
# repris - NORP
# paul atreid - PERSON
# includ javier bardem stilgar rebecca ferguson - PERSON
# two - CARDINAL
# spectacl substanc - ORG
# thrill - GPE
# two - CARDINAL
# everi narr - PERSON
# two - CARDINAL
#
# Entities in text 979:
# oppenheim nuke - PERSON
# piqu paul - PERSON
# paul artreidi chani - PERSON
#
# Entities in text 980:
# first - ORDINAL
# happen quit year - DATE
# two - CARDINAL
# paul - PERSON
# rememb paul - PERSON
# cri - NORP
# paul - PERSON
#
# Entities in text 981:
# deni villeneuv - PERSON
# reveng - PERSON
# first - ORDINAL
# paul atreid - PERSON
# genr one - PRODUCT
# one - CARDINAL
# paul - PERSON
# lisan al gaib - PERSON
# deni villeneuv - PERSON
# recent year - DATE
# one - CARDINAL
# paul - PERSON
# austin butler feydrautha - PERSON
# prais howev feydrautha sadli - PERSON
# issu - PERSON
# potenti fulli - PERSON
# javier bardem - PERSON
# brolin aveng - PERSON
# chemistri abil - PERSON
# beauti - CARDINAL
# hseri - NORP
# soviet - NORP
# simpli mesmeris - PERSON
# han - NORP
# arraki emerg - PERSON
# two - CARDINAL
# han zimmerdeni - PERSON
# recent year - DATE
# hour - TIME
#
# Entities in text 982:
# everi way filmmak - PERSON
# max metropoli - PERSON
# beauti horrifi - PERSON
# six - CARDINAL
#
# Entities in text 983:
# two - CARDINAL
# two - CARDINAL
# two - CARDINAL
# genr one - PRODUCT
# everi view anyon - PERSON
#
# Entities in text 984:
# two - CARDINAL
# invit - ORG
# mesmer narr - PERSON
# reveng - PERSON
# paul atreid - PERSON
# narr - PERSON
# breathtak cinematographyth - PERSON
# greig fraser - PERSON
# appar result visual - PERSON
# imageri - NORP
# paul atreid - PERSON
# timotth - ORG
# revengeth narrat - PERSON
# paul - PERSON
# han - NORP
# frank herbert materi one film visual - PERSON
# narr - ORG
# spectacl power - ORG
# storytellingon highlight movi - ORG
# jessica - PERSON
# one - CARDINAL
# paul ferguson - PERSON
# infus - NORP
# javier bardem dave bautista - PERSON
# paul intent - PERSON
# nativ - GPE
# newcom bautista rabban brutal - PERSON
# josh brolin charlott - ORG
# narr paul chani - PERSON
# fateth - LOC
# narr - PERSON
# paul - PERSON
# spectacl substanc - ORG
# herbert sourc materi - PERSON
# paul - PERSON
# narr invit - PERSON
# paul - PERSON
# two - CARDINAL
# reveng - PERSON
# deni villeneuv - PERSON
# two - CARDINAL
#
# Entities in text 985:
# two - CARDINAL
# narr grip movi - ORG
# deni villeneuv - PERSON
# seri - NORP
# fulli - PERSON
# second - ORDINAL
# seri - NORP
# first - ORDINAL
#
# Entities in text 986:
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
# movi detail actual actual - ORG
# third - ORDINAL
#
# Entities in text 987:
# one - CARDINAL
# deni villeneuv - PERSON
# one - CARDINAL
# undescrib experi - GPE
# han - NORP
#
# Entities in text 988:
# today - DATE
#
# Entities in text 989:
# two - CARDINAL
# solidifi deni villeneuv one - PERSON
# first - ORDINAL
# eleven - CARDINAL
# newcom darker depth figur - ORG
# one - CARDINAL
# frank herbert novel - PERSON
# two - CARDINAL
# first - ORDINAL
# bamboozl mani - PERSON
# one - CARDINAL
# frank herbert son brian - PERSON
# one - CARDINAL
# one - CARDINAL
# jessica paul - PERSON
# believ paul - ORG
# vile harkonnen - ORG
# one - CARDINAL
# battl sandworm - PERSON
# austin butler feyd rautha - PERSON
# anton - PERSON
# newcom includ - PERSON
# fenr - ORG
# includ javier bardem - PERSON
# josh brolin - PERSON
# halleck harkonnen - ORG
# harkonnen dave bautista beast - PERSON
# feyd charlott - ORG
# paul chani - PERSON
# one - CARDINAL
# believ paul - ORG
# conqueror sandworm - PERSON
# first - ORDINAL
# seri - NORP
# paul - PERSON
# jessica - NORP
# paul atreid specif - PERSON
#
# Entities in text 990:
# sourc materi - PERSON
# sourc materi - PERSON
# bookdeni - NORP
# paul intern - PERSON
# battl forc - PERSON
# spectacl watch movi - ORG
# deni know chang - PERSON
# qualm chang - PERSON
# deni - PERSON
#
# Entities in text 991:
# liter jaw - PERSON
# slightli - GPE
# million - CARDINAL
# million - CARDINAL
# dunedeni villeneuv - PERSON
#
# Entities in text 992:
# sourc materi - PERSON
# one - CARDINAL
# materi - PERSON
# chang - PERSON
# materi detail - PERSON
# essenti captur - PERSON
# chang - PERSON
# materi - PERSON
# howev dune nerd - WORK_OF_ART
# frank herbert - PERSON
# bum chang - PERSON
# vaniti - GPE
# marilyn manson - PERSON
# one - CARDINAL
# second - ORDINAL
# half - CARDINAL
# austin butler feydrautha actual - PERSON
# javier bardem stilgar enjoy - PERSON
# provid smart - PERSON
# believ believ perfectli place trailer - ORG
# first - ORDINAL
# han - NORP
# musica - PRODUCT
# everi singl - PERSON
# one - CARDINAL
# expertli craft climat final - ORG
# first - ORDINAL
# lightli - PERSON
# year - DATE
# qualiti - GPE
#
# Entities in text 993:
# everi scene - PERSON
# one - CARDINAL
# two - CARDINAL
# knight rrr mandalorianseri - PERSON
# bawaal movi - ORG
# awesom - PERSON
#
# Entities in text 994:
# one - CARDINAL
# everi second - PERSON
# han - NORP
# experi fill beauti shoot - PERSON
# everi - ORG
# one - CARDINAL
# year later - DATE
# guarante deni villeneuv - PERSON
# one - CARDINAL
# gener - PERSON
# everi - NORP
# sci fi fantasi - ORG
# one - CARDINAL
# one - CARDINAL
# show movi sinc - ORG
#
# Entities in text 995:
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# storylin - GPE
# frank herbert book - PERSON
# sourc materi - ORG
# spectacl - ORG
# surpris - NORP
# rang abilityzendaya - PERSON
# secondari - ORG
# signific subtext sadli - ORG
# deni villeneuv - PERSON
# spectacl - ORG
# beth costum - PERSON
# one - CARDINAL
#
# Entities in text 996:
# deni villeneuv - PERSON
# two - CARDINAL
# one - CARDINAL
# han - NORP
# austin - PERSON
# everi moviego experi - PERSON
#
# Entities in text 997:
# one - CARDINAL
# one hour - TIME
# chang - PERSON
# subtitl - PERSON
# prais movi - ORG
# mayb reason - PERSON
#
# Entities in text 998:
# two film hour - TIME
# storylin - DATE
# hour - TIME
#
# Entities in text 999:
# first - ORDINAL
# gistpaul battl - PERSON
# chani paul - PERSON
# feyd - PERSON
# someon crazi - PERSON
# threatth whole movi - ORG
# second - ORDINAL
# half - CARDINAL
# one - CARDINAL
# austin butler - PERSON
# experi - NORP
# onei - GPE
# first - ORDINAL
#
# Entities in text 1000:
# two - CARDINAL
# tragedi tell big canva imagin - ORG
# everi depart - PERSON
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# chemistri zendaya begin truli - PERSON
# essenti becom - PERSON
# fulli - PERSON
# psychot honestli - PERSON
# first - ORDINAL
# bath beauti orang - PERSON
# deni villeneuv - PERSON
# one - CARDINAL
# undeni - NORP
# han - NORP
# one - CARDINAL
# one - CARDINAL
#
# Total entity counts:
# GPE: 233
# PERSON: 3099
# CARDINAL: 1408
# ORDINAL: 1010
# DATE: 269
# ORG: 915
# WORK_OF_ART: 17
# NORP: 399
# TIME: 166
# PRODUCT: 65
# LANGUAGE: 3
# QUANTITY: 6
# EVENT: 7
# FAC: 16
# LOC: 8
# LAW: 4
# MONEY: 1
#
# Sample of unique entities found (up to 20):
# howev read book part movi like right bookth - WORK_OF_ART
# deni visual movi fantast - ORG
# beauti technic - PERSON
# jessica fierc - PERSON
# paul feyd mani - PERSON
# someon el - PERSON
# interferencedeni - NORP
# deni villanuev manag - PERSON
# someth describ - ORG
# paul one chang sign reveal paul - PERSON
# measur unfortun - PERSON
# sceneri philosophi - ORG
# honestli surpris - PERSON
# austin butler steal show - PERSON
# khartoum - GPE
# sci fi fantasi - ORG
# measur approach - PERSON
# creativ movi - ORG
# gurney halleck - PERSON
# staggeringit - GPE
#
# Full list of named entities saved to 'named_entities.csv'

# %% [markdown]
# #**Comment**
# Make sure to submit the cleaned data CSV in the comment section - 10 points

# %%
# Saved the final cleaned and the processed dataset to a CSV file
dataFrame.to_csv('final_cleaned_dataset.csv', index=False)

# Print a confirmation message
print("Final cleaned dataset with all steps saved to 'final_cleaned_dataset.csv'")
# Out:
# Final cleaned dataset with all steps saved to 'final_cleaned_dataset.csv'

# %%
import pandas as pd

# Loading  the final cleaned CSV file
dataFrame = pd.read_csv('final_cleaned_dataset.csv')

# Keeping  only the final cleaned 'Lemmatized' column since it is the last step performed and renamed it to 'Final Review'
final_dataFrame = dataFrame[['Lemmatized']].rename(columns={'Lemmatized': 'Final Review'})

# Saving the entire final-dataset to new CSV-file called as final_reviews_dataset
final_dataFrame.to_csv('final_reviews_dataset.csv', index=False)

# Print a final confirmation message
print("Cleaned and Final reviews dataset has been saved to 'final_reviews_dataset.csv'")
# Out:
# Cleaned and Final reviews dataset has been saved to 'final_reviews_dataset.csv'

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below

'''
1. The first and foremost main challenge which i faced is thw web scraping, Here we have collected the data from various sources , in our case, the IMDB url which is a dynamic-content -loading dataset, it is always tricky because of this content loading and also other tricky part is pagination, and also we should not get blocked by the server. It has also been difficult to handle the pagination of such huge number of pages and a vast number of reviews which are 1000 efficiently wothout over-loading the server.
2. Next challenge which i faced is in text cleaning, i have implemented different kinds of text pre-processing technqiues like removal of the noise, then handling the stop words, stemming and also lemmatization which requires the attention to detail. If stemming and lemmatization are not being handled correctly, there is a high chance that they can even alter the entire meaning of the text.
3. The other challenge which i felt was applying the POS tagging , parsing which require a lot of undetstanding on the lingustic structures and also implementing all these things correctly can be quite challenging.

The enjoyable aspects which i felt in this assignment are that , i ahve explore libraries such as beautiful soup for the purpose of web scraping and also using idataFrameferent kinds of libraries like the Spacy and NLTK for the text pre-processing.

And also, once the entire data has been cleaned, we analysed the text using the POS tagging and also extracting different entities using the NER provided me with valuable information/insights into data. It was very interesting to learn how much information can be extracted from the raw data or the raw-text.

My final thoughts are that , This assignment comprised of multiple concepts like the web scraping, text pre processing and the advanced text-analytics which helped me gaing more insights on all these topics together.

The assignment comprised of multiple tasks, so it require lot of attention and detail but it is a good practise for hands on experience. The time provided is sufficeint for some one whoc is already familiar with all the libraries and the techniques, but it is time intensive, additional time can be provided so that we can grasp more concepts and preopley give the solutions
'''
# Out:
# '\n1. The first and foremost main challenge which i faced is thw web scraping, Here we have collected the data from various sources , in our case, the IMDB url which is a dynamic-content -loading dataset, it is always tricky because of this content loading and also other tricky part is pagination, and also we should not get blocked by the server. It has also been difficult to handle the pagination of such huge number of pages and a vast number of reviews which are 1000 efficiently wothout over-loading the server.\n2. Next challenge which i faced is in text cleaning, i have implemented different kinds of text pre-processing technqiues like removal of the noise, then handling the stop words, stemming and also lemmatization which requires the attention to detail. If stemming and lemmatization are not being handled correctly, there is a high chance that they can even alter the entire meaning of the text.\n3. The other challenge which i felt was applying the POS tagging , parsing which require a lot of undetstanding on the lingustic structures and also implementing all these things correctly can be quite challenging.\n\nThe enjoyable aspects which i felt in this assignment are that , i ahve explore libraries such as beautiful soup for the purpose of web scraping and also using idataFrameferent kinds of libraries like the Spacy and NLTK for the text pre-processing.\n\nAnd also, once the entire data has been cleaned, we analysed the text using the POS tagging and also extracting different entities using the NER provided me with valuable information/insights into data. It was very interesting to learn how much information can be extracted from the raw data or the raw-text.\n\nMy final thoughts are that , This assignment comprised of multiple concepts like the web scraping, text pre processing and the advanced text-analytics which helped me gaing more insights on all these topics together.\n\nThe assignment comprised of multiple tasks, so it require lot of attention and detail but it is a good practise for hands on experience. The time provided is sufficeint for some one whoc is already familiar with all the libraries and the techniques, but it is time intensive, additional time can be provided so that we can grasp more concepts and preopley give the solutions\n'
